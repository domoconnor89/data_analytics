# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
start_set = {'category': [],
             'month' : [],
             'year' : [],
             'clicks' : []
           }

full_set = pd.DataFrame(start_set)

# %%
num = 1

def parse_dataset(num):
    file_path = f'../data/pis_{num}.csv'
    df = pd.read_csv(file_path)#, names = ['category', 'month', 'year', 'clicks'])
    return df

# %%
for num in range(1, 101):
    temp_df = parse_dataset(num)
    #df['year'] = year
    full_set = pd.concat([temp_df, full_set])

# %%
df = full_set.reset_index(drop=True)

# %% [markdown]
# # Tasks
# ### Create an analysis to help the content team and answer following questions:
#
# 1. Is there a seasonal pattern for all categories?
# 2. What are common patterns that we observe within the categories?
# 3. Are there categories with a similar fingerprint?
# 4. Now that you know the seasonal pattern, what next actions would you recommend for the company?
# 5. Create a presentation to show what you did. Make your results accessible for a broad audience so that they can use it.

# %%
df['category'].nunique()
# Out:
# 100

# %%
## CHECK FOR NA's

df.isnull().sum()
# Out:
# category     0
# month        0
# year         0
# clicks      30
# dtype: int64

# %%
null_index = df[df['clicks'].isnull()].index.tolist()

# %%
df = df.sort_values(by=['category','month']).reset_index(drop=True)

# %%
## FILL NA VALUES WITH AN AVG TAKEN FROM VALUE ABOVE & BELOW

df['clicks'] = df['clicks'].fillna((df['clicks'].shift() + df['clicks'].shift(-1)) / 2)

# %%
imputed_vals = df.loc[null_index].reset_index(drop=True)
imputed_vals = imputed_vals[['category','month','clicks','avg_cat_clicks']].sort_values(by=['category','month'])
imputed_vals['imputed_clicks'] = imputed_vals['clicks']
imputed_vals['imputed_diff_avg'] = (imputed_vals['imputed_clicks'] - imputed_vals['avg_cat_clicks'])
imputed_vals = imputed_vals[['category','month','avg_cat_clicks','imputed_clicks','imputed_diff_avg']]
imputed_vals
# Out:
#                            category  month  avg_cat_clicks  imputed_clicks  \
# 0                    All-in-One PCs      6    76766.416667           52846
# 1                     Drills & Bits      5    68036.666667           67636
# 2           Epilators & Ladyshavers     10    61210.000000           41129
# 3         Eye, Ear & Nose Medicines      4    56615.916667           61113
# 4       Joint & muscle preparations      3    84028.166667           95780
# 5                 Nursing Gift Sets      7    52633.083333           39030
# 6                         PowerLine      7    69059.166667           63422
# 7      Razor Blades & Shaving Heads     11    76386.333333           97742
# 8      Razor Blades & Shaving Heads     12    76386.333333           75069
# 9   Ski helmets & snowboard helmets      2    76446.666667          141912
# 10                   Xbox One games      2    65384.166667           54917
# 11                       bike locks     11    75646.166667           48196
# 12                 capsule machines      7    87970.916667           69061
# 13                 children's bikes     12    76862.416667           67219
# 14              coffee pad machines      5    64044.333333           48442
# 15                 control software      8    74114.000000           26664
# 16                 drinking bottles      9    59664.916667           68354
# 17                           fryers     11    86091.416667          158620
# 18                     garden pumps      7    77264.666667          127392
# 19                         liqueurs     12    62797.916667          104000
# 20                       mattresses      1    73678.916667           96388
# 21              multifunction tools      6    62304.833333           47888
# 22                     pocket knife      4    61354.083333           53184
# 23                     pocket knife     12    61354.083333           79294
# 24                  sewing machines      5    60585.666667           46620
# 25                    shopping bags      3    70157.250000           60420
# 26                    shopping bags     10    70157.250000           57971
# 27                  stuffed animals      4    67856.916667           50308
# 28                 trekking sandals      2    57862.500000           27396
# 29                     washer dryer     10    63417.166667           72819
#
#     imputed_diff_avg
# 0      -23920.416667
# 1        -400.666667
# 2      -20081.000000
# 3        4497.083333
# 4       11751.833333
# 5      -13603.083333
# 6       -5637.166667
# 7       21355.666667
# 8       -1317.333333
# 9       65465.333333
# 10     -10467.166667
# 11     -27450.166667
# 12     -18909.916667
# 13      -9643.416667
# 14     -15602.333333
# 15     -47450.000000
# 16       8689.083333
# 17      72528.583333
# 18      50127.333333
# 19      41202.083333
# 20      22709.083333
# 21     -14416.833333
# 22      -8170.083333
# 23      17939.916667
# 24     -13965.666667
# 25      -9737.250000
# 26     -12186.250000
# 27     -17548.916667
# 28     -30466.500000
# 29       9401.833333

# %%
imputed_vals.to_csv('../data/imputed_vals.csv', index=False)

# %%
## CONVERT FLOATS TO INTEGERS

df['year'] = df['year'].astype(int)
df['month'] = df['month'].astype(int)
df['clicks'] = df['clicks'].astype(int)

# %%
df.shape
# Out:
# (1200, 4)

# %%
## BIN MONTHS INTO SEASONS

# %%
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Autumn'
    else:
        return 'Unknown'

# Apply the function to create a new 'Season' column
df['season'] = df['month'].apply(get_season)
df=df[['category','year','season','month','clicks']]
df
# Out:
#                                 category  year  season  month  clicks
# 0     Accessories for kitchen appliances  2021  Winter      1   81676
# 1     Accessories for kitchen appliances  2021  Winter      2   59529
# 2     Accessories for kitchen appliances  2021  Spring      3   64537
# 3     Accessories for kitchen appliances  2021  Spring      4   55455
# 4     Accessories for kitchen appliances  2021  Spring      5   52882
# ...                                  ...   ...     ...    ...     ...
# 1195                        washer dryer  2021  Summer      8   54857
# 1196                        washer dryer  2021  Autumn      9   63418
# 1197                        washer dryer  2021  Autumn     10   72819
# 1198                        washer dryer  2021  Autumn     11  101180
# 1199                        washer dryer  2021  Winter     12   70415
#
# [1200 rows x 5 columns]

# %%
## ADD COLUMNS FOR AVG etc

# %%
df['ttl_cat_clicks'] = df.groupby('category')['clicks'].transform('sum')

df['min_cat_clicks'] = df.groupby('category')['clicks'].transform('min')
df['avg_cat_clicks'] = df.groupby('category')['clicks'].transform('mean')
df['max_cat_clicks'] = df.groupby('category')['clicks'].transform('max')

df['std_cat_clicks'] = df.groupby('category')['clicks'].transform('std')

df['co_var_cat']=(df['std_cat_clicks'] / df['avg_cat_clicks']) * 100

    ## The idxmin function is used to find the index (which corresponds to the month) 
    ## where the minimum value occurs within each group.

min_month_per_category = df.loc[df.groupby('category')['clicks'].idxmin()][['category', 'month']]
max_month_per_category = df.loc[df.groupby('category')['clicks'].idxmax()][['category', 'month']]


df_merged = pd.merge(df, min_month_per_category, on='category', how='left', suffixes=('', '_min_clicks'))
df_merged2 = pd.merge(df_merged, max_month_per_category, on='category', how='left', suffixes=('', '_max_clicks'))
df_merged2


df = df_merged2[['category','year','season','month','clicks',
                 'ttl_cat_clicks','month_min_clicks','min_cat_clicks',
                 'max_cat_clicks','month_max_clicks',
                 'avg_cat_clicks','std_cat_clicks','co_var_cat']]

df['mnth_ranking'] = df.groupby('category')['clicks'].rank(ascending=False)
df
# Out:
# /var/folders/zf/w4lxv8m15z9442k97fpp97ch0000gn/T/ipykernel_12513/4082481783.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mnth_ranking'] = df.groupby('category')['clicks'].rank(ascending=False)
#                                 category  year  season  month  clicks  \
# 0     Accessories for kitchen appliances  2021  Winter      1   81676
# 1     Accessories for kitchen appliances  2021  Winter      2   59529
# 2     Accessories for kitchen appliances  2021  Spring      3   64537
# 3     Accessories for kitchen appliances  2021  Spring      4   55455
# 4     Accessories for kitchen appliances  2021  Spring      5   52882
# ...                                  ...   ...     ...    ...     ...
# 1195                        washer dryer  2021  Summer      8   54857
# 1196                        washer dryer  2021  Autumn      9   63418
# 1197                        washer dryer  2021  Autumn     10   72819
# 1198                        washer dryer  2021  Autumn     11  101180
# 1199                        washer dryer  2021  Winter     12   70415
#
#       ttl_cat_clicks  month_min_clicks  min_cat_clicks  max_cat_clicks  \
# 0             774200                 6           41856          118898
# 1             774200                 6           41856          118898
# 2             774200                 6           41856          118898
# 3             774200                 6           41856          118898
# 4             774200                 6           41856          118898
# ...              ...               ...             ...             ...
# 1195          761006                 6           46658          101180
# 1196          761006                 6           46658          101180
# 1197          761006                 6           46658          101180
# 1198          761006                 6           46658          101180
# 1199          761006                 6           46658          101180
#
#       month_max_clicks  avg_cat_clicks  std_cat_clicks  co_var_cat  \
# 0                   12    64516.666667    24704.093137   38.291025
# 1                   12    64516.666667    24704.093137   38.291025
# 2                   12    64516.666667    24704.093137   38.291025
# 3                   12    64516.666667    24704.093137   38.291025
# 4                   12    64516.666667    24704.093137   38.291025
# ...                ...             ...             ...         ...
# 1195                11    63417.166667    15479.855689   24.409567
# 1196                11    63417.166667    15479.855689   24.409567
# 1197                11    63417.166667    15479.855689   24.409567
# 1198                11    63417.166667    15479.855689   24.409567
# 1199                11    63417.166667    15479.855689   24.409567
#
#       mnth_ranking
# 0              3.0
# 1              5.0
# 2              4.0
# 3              7.0
# 4              8.0
# ...            ...
# 1195           7.0
# 1196           6.0
# 1197           3.0
# 1198           1.0
# 1199           4.0
#
# [1200 rows x 14 columns]

# %%
df.to_csv('../data/combined_smartbuy.csv', index=False)

# %% [raw]
# df_prep = df[['category','month','mnth_ranking','clicks',
#                  'ttl_cat_clicks','month_min_clicks','min_cat_clicks','max_cat_clicks','month_max_clicks',
#                  'avg_cat_clicks','std_cat_clicks','co_var_cat']]
# df_prep

# %% [raw]
# df_piv = df.pivot(index='category', columns='month', values='clicks')
# df_piv = df_piv.reset_index()
# df_piv
# #df_piv.reset_index()

# %% [raw]
# df_piv.rename(columns={'1': 'jan_clcks','2':'feb_clcks','3':'mar_clcks',
#                        '4':'apr_clcks','5':'may_clcks','6':'jun_clcks',
#                        '7':'jul_clcks','8':'aug_clcks','9':'sep_clcks',
#                        '10':'oct_clcks','11':'nov_clcks','12':'dec_clcks'}, inplace=True)
# #df_piv

# %%
agg_df = df[['category','ttl_cat_clicks','month_min_clicks','min_cat_clicks',
             'max_cat_clicks','month_max_clicks',
             'avg_cat_clicks','std_cat_clicks','co_var_cat',]]

agg_df.drop_duplicates(subset='category', keep='first', inplace=True)
agg_df.reset_index(drop=True, inplace=True)

agg_df
# Out:
# /var/folders/zf/w4lxv8m15z9442k97fpp97ch0000gn/T/ipykernel_12513/1467625562.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agg_df.drop_duplicates(subset='category', keep='first', inplace=True)
#                                 category  ttl_cat_clicks  month_min_clicks  \
# 0     Accessories for kitchen appliances          774200                 6
# 1                         All-in-One PCs          921197                 6
# 2   Champagne, Sparkling Wine & Prosecco          656334                 6
# 3                      Coffee & espresso          621284                 6
# 4                Coffee machine cleaning          700288                 6
# ..                                   ...             ...               ...
# 95                            tracksuits          908321                 6
# 96                      trekking sandals          694350                12
# 97                             turntable          643784                 8
# 98                             umbrellas          737030                12
# 99                          washer dryer          761006                 6
#
#     min_cat_clicks  max_cat_clicks  month_max_clicks  avg_cat_clicks  \
# 0            41856          118898                12    64516.666667
# 1            52846          134469                11    76766.416667
# 2            43985           81142                11    54694.500000
# 3            36226           61849                 3    51773.666667
# 4            44302           81720                 1    58357.333333
# ..             ...             ...               ...             ...
# 95           53258           97270                11    75693.416667
# 96           14641          143488                 6    57862.500000
# 97           35788           86713                12    53648.666667
# 98            8408          160126                 6    61419.166667
# 99           46658          101180                11    63417.166667
#
#     std_cat_clicks  co_var_cat
# 0     24704.093137   38.291025
# 1     23784.127352   30.982464
# 2     11131.379858   20.351918
# 3      6848.562149   13.227887
# 4      9751.063796   16.709235
# ..             ...         ...
# 95    13233.028695   17.482404
# 96    45773.249408   79.106934
# 97    18823.303702   35.086247
# 98    53278.747391   86.746125
# 99    15479.855689   24.409567
#
# [100 rows x 9 columns]

# %%
agg_df.sort_values(by='co_var_cat').head(20)

# %%
agg_df.to_csv('../data/agg_smartbuy.csv', index=False)

# %%
df_num = agg_df.set_index('category').transpose()
df_num
# Out:
# category          Accessories for kitchen appliances  All-in-One PCs  \
# ttl_cat_clicks                         774200.000000   921197.000000
# month_min_clicks                            6.000000        6.000000
# min_cat_clicks                          41856.000000    52846.000000
# max_cat_clicks                         118898.000000   134469.000000
# month_max_clicks                           12.000000       11.000000
# avg_cat_clicks                          64516.666667    76766.416667
# std_cat_clicks                          24704.093137    23784.127352
# co_var_cat                                 38.291025       30.982464
#
# category          Champagne, Sparkling Wine & Prosecco  Coffee & espresso  \
# ttl_cat_clicks                           656334.000000      621284.000000
# month_min_clicks                              6.000000           6.000000
# min_cat_clicks                            43985.000000       36226.000000
# max_cat_clicks                            81142.000000       61849.000000
# month_max_clicks                             11.000000           3.000000
# avg_cat_clicks                            54694.500000       51773.666667
# std_cat_clicks                            11131.379858        6848.562149
# co_var_cat                                   20.351918          13.227887
#
# category          Coffee machine cleaning  Drills & Bits  \
# ttl_cat_clicks              700288.000000  816440.000000
# month_min_clicks                 6.000000       2.000000
# min_cat_clicks               44302.000000   52772.000000
# max_cat_clicks               81720.000000   87129.000000
# month_max_clicks                 1.000000      10.000000
# avg_cat_clicks               58357.333333   68036.666667
# std_cat_clicks                9751.063796   10828.154576
# co_var_cat                      16.709235      15.915175
#
# category          Epilators & Ladyshavers  Eye, Ear & Nose Medicines  \
# ttl_cat_clicks              734520.000000              679391.000000
# month_min_clicks                 2.000000                   8.000000
# min_cat_clicks               35819.000000               48186.000000
# max_cat_clicks               93155.000000               66167.000000
# month_max_clicks                11.000000                   1.000000
# avg_cat_clicks               61210.000000               56615.916667
# std_cat_clicks               17145.890236                6262.510598
# co_var_cat                      28.011583                  11.061396
#
# category          Fireplaces & Stoves    Garbage can  ...         stylus  \
# ttl_cat_clicks          859562.000000  760390.000000  ...  787384.000000
# month_min_clicks             6.000000       6.000000  ...       6.000000
# min_cat_clicks           25040.000000   47930.000000  ...   35969.000000
# max_cat_clicks          132857.000000   76567.000000  ...  126711.000000
# month_max_clicks            11.000000       1.000000  ...      11.000000
# avg_cat_clicks           71630.166667   63365.833333  ...   65615.333333
# std_cat_clicks           36987.834486    8261.293701  ...   32118.907853
# co_var_cat                  51.637231      13.037458  ...      48.950308
#
# category               sun care  thermos flasks   thermostats   toy vehicles  \
# ttl_cat_clicks    822477.000000   733768.000000  1.049359e+06  823536.000000
# month_min_clicks      12.000000        9.000000  6.000000e+00       6.000000
# min_cat_clicks     26556.000000    34906.000000  2.853000e+04   25911.000000
# max_cat_clicks    180883.000000    97556.000000  1.989690e+05  200438.000000
# month_max_clicks       6.000000        1.000000  1.100000e+01      12.000000
# avg_cat_clicks     68539.750000    61147.333333  8.744658e+04   68628.000000
# std_cat_clicks     48369.255935    19172.446903  5.427833e+04   59480.538198
# co_var_cat            70.571101       31.354510  6.207027e+01      86.670948
#
# category             tracksuits  trekking sandals      turntable  \
# ttl_cat_clicks    908321.000000     694350.000000  643784.000000
# month_min_clicks       6.000000         12.000000       8.000000
# min_cat_clicks     53258.000000      14641.000000   35788.000000
# max_cat_clicks     97270.000000     143488.000000   86713.000000
# month_max_clicks      11.000000          6.000000      12.000000
# avg_cat_clicks     75693.416667      57862.500000   53648.666667
# std_cat_clicks     13233.028695      45773.249408   18823.303702
# co_var_cat            17.482404         79.106934      35.086247
#
# category              umbrellas   washer dryer
# ttl_cat_clicks    737030.000000  761006.000000
# month_min_clicks      12.000000       6.000000
# min_cat_clicks      8408.000000   46658.000000
# max_cat_clicks    160126.000000  101180.000000
# month_max_clicks       6.000000      11.000000
# avg_cat_clicks     61419.166667   63417.166667
# std_cat_clicks     53278.747391   15479.855689
# co_var_cat            86.746125      24.409567
#
# [8 rows x 100 columns]

# %%
df_corr = df_num.corr()
df_corr
# Out:
# category                              Accessories for kitchen appliances  \
# category
# Accessories for kitchen appliances                              1.000000
# All-in-One PCs                                                  0.999944
# Champagne, Sparkling Wine & Prosecco                            0.999292
# Coffee & espresso                                               0.998338
# Coffee machine cleaning                                         0.999084
# ...                                                                  ...
# tracksuits                                                      0.998761
# trekking sandals                                                0.997126
# turntable                                                       0.999807
# umbrellas                                                       0.995703
# washer dryer                                                    0.999675
#
# category                              All-in-One PCs  \
# category
# Accessories for kitchen appliances          0.999944
# All-in-One PCs                              1.000000
# Champagne, Sparkling Wine & Prosecco        0.999626
# Coffee & espresso                           0.998840
# Coffee machine cleaning                     0.999467
# ...                                              ...
# tracksuits                                  0.999188
# trekking sandals                            0.996277
# turntable                                   0.999920
# umbrellas                                   0.994682
# washer dryer                                0.999885
#
# category                              Champagne, Sparkling Wine & Prosecco  \
# category
# Accessories for kitchen appliances                                0.999292
# All-in-One PCs                                                    0.999626
# Champagne, Sparkling Wine & Prosecco                              1.000000
# Coffee & espresso                                                 0.999700
# Coffee machine cleaning                                           0.999972
# ...                                                                    ...
# tracksuits                                                        0.999847
# trekking sandals                                                  0.993599
# turntable                                                         0.999765
# umbrellas                                                         0.991561
# washer dryer                                                      0.999924
#
# category                              Coffee & espresso  \
# category
# Accessories for kitchen appliances             0.998338
# All-in-One PCs                                 0.998840
# Champagne, Sparkling Wine & Prosecco           0.999700
# Coffee & espresso                              1.000000
# Coffee machine cleaning                        0.999851
# ...                                                 ...
# tracksuits                                     0.999968
# trekking sandals                               0.991530
# turntable                                      0.999247
# umbrellas                                      0.989285
# washer dryer                                   0.999429
#
# category                              Coffee machine cleaning  Drills & Bits  \
# category
# Accessories for kitchen appliances                   0.999084       0.998616
# All-in-One PCs                                       0.999467       0.999087
# Champagne, Sparkling Wine & Prosecco                 0.999972       0.999856
# Coffee & espresso                                    0.999851       0.999962
# Coffee machine cleaning                              1.000000       0.999945
# ...                                                       ...            ...
# tracksuits                                           0.999945       0.999978
# trekking sandals                                     0.993088       0.991970
# turntable                                            0.999676       0.999414
# umbrellas                                            0.990997       0.989742
# washer dryer                                         0.999845       0.999614
#
# category                              Epilators & Ladyshavers  \
# category
# Accessories for kitchen appliances                   0.999631
# All-in-One PCs                                       0.999799
# Champagne, Sparkling Wine & Prosecco                 0.999772
# Coffee & espresso                                    0.999472
# Coffee machine cleaning                              0.999757
# ...                                                       ...
# tracksuits                                           0.999684
# trekking sandals                                     0.995222
# turntable                                            0.999947
# umbrellas                                            0.993498
# washer dryer                                         0.999895
#
# category                              Eye, Ear & Nose Medicines  \
# category
# Accessories for kitchen appliances                     0.997889
# All-in-One PCs                                         0.998490
# Champagne, Sparkling Wine & Prosecco                   0.999607
# Coffee & espresso                                      0.999905
# Coffee machine cleaning                                0.999745
# ...                                                         ...
# tracksuits                                             0.999834
# trekking sandals                                       0.990282
# turntable                                              0.998905
# umbrellas                                              0.987838
# washer dryer                                           0.999206
#
# category                              Fireplaces & Stoves  Garbage can  ...  \
# category                                                                ...
# Accessories for kitchen appliances               0.999558     0.998308  ...
# All-in-One PCs                                   0.999288     0.998829  ...
# Champagne, Sparkling Wine & Prosecco             0.998152     0.999735  ...
# Coffee & espresso                                0.997277     0.999988  ...
# Coffee machine cleaning                          0.997982     0.999868  ...
# ...                                                   ...          ...  ...
# tracksuits                                       0.997770     0.999958  ...
# trekking sandals                                 0.998326     0.991326  ...
# turntable                                        0.999219     0.999218  ...
# umbrellas                                        0.997309     0.989033  ...
# washer dryer                                     0.998779     0.999437  ...
#
# category                                stylus  sun care  thermos flasks  \
# category
# Accessories for kitchen appliances    0.999880  0.996961        0.999779
# All-in-One PCs                        0.999668  0.996114        0.999878
# Champagne, Sparkling Wine & Prosecco  0.998646  0.993341        0.999665
# Coffee & espresso                     0.997551  0.990918        0.999225
# Coffee machine cleaning               0.998399  0.992728        0.999611
# ...                                        ...       ...             ...
# tracksuits                            0.998062  0.991926        0.999491
# trekking sandals                      0.998127  0.999807        0.995866
# turntable                             0.999496  0.995326        0.999967
# umbrellas                             0.996958  0.999628        0.994247
# washer dryer                          0.999200  0.994665        0.999869
#
# category                              thermostats  toy vehicles  tracksuits  \
# category
# Accessories for kitchen appliances       0.998588      0.994636    0.998761
# All-in-One PCs                           0.997986      0.993527    0.999188
# Champagne, Sparkling Wine & Prosecco     0.995916      0.990078    0.999847
# Coffee & espresso                        0.994227      0.987103    0.999968
# Coffee machine cleaning                  0.995517      0.989301    0.999945
# ...                                           ...           ...         ...
# tracksuits                               0.995002      0.988317    1.000000
# trekking sandals                         0.999725      0.999302    0.992473
# turntable                                0.997536      0.992525    0.999522
# umbrellas                                0.999204      0.999502    0.990335
# washer dryer                             0.996947      0.991692    0.999661
#
# category                              trekking sandals  turntable  umbrellas  \
# category
# Accessories for kitchen appliances            0.997126   0.999807   0.995703
# All-in-One PCs                                0.996277   0.999920   0.994682
# Champagne, Sparkling Wine & Prosecco          0.993599   0.999765   0.991561
# Coffee & espresso                             0.991530   0.999247   0.989285
# Coffee machine cleaning                       0.993088   0.999676   0.990997
# ...                                                ...        ...        ...
# tracksuits                                    0.992473   0.999522   0.990335
# trekking sandals                              1.000000   0.995701   0.999855
# turntable                                     0.995701   1.000000   0.994019
# umbrellas                                     0.999855   0.994019   1.000000
# washer dryer                                  0.994899   0.999932   0.993065
#
# category                              washer dryer
# category
# Accessories for kitchen appliances        0.999675
# All-in-One PCs                            0.999885
# Champagne, Sparkling Wine & Prosecco      0.999924
# Coffee & espresso                         0.999429
# Coffee machine cleaning                   0.999845
# ...                                            ...
# tracksuits                                0.999661
# trekking sandals                          0.994899
# turntable                                 0.999932
# umbrellas                                 0.993065
# washer dryer                              1.000000
#
# [100 rows x 100 columns]
