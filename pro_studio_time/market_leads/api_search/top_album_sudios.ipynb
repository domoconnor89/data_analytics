# %%
import requests
import os
import base64
import csv
import time
from datetime import datetime
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Spotify API credentials
CLIENT_ID = os.getenv('CLIENT_ID')
CLIENT_SECRET = os.getenv('CLIENT_SECRET')

# Discogs API credentials
discogs_token = os.getenv('discogs_token')
user_agent = os.getenv('USER_AGENT')

# Validate credentials
if not CLIENT_ID or not CLIENT_SECRET or not discogs_token or not user_agent:
    raise ValueError("API credentials or User-Agent are missing! Please check your .env file.")

def top_album_studios(limit, min_yr, max_yr, mrkt):
    """
    Fetch top albums from Spotify and retrieve their recording studios from Discogs.
    Results are saved to a CSV file.
    
    Parameters:
        limit (int): Total number of albums to fetch per year from Spotify (up to 1,000).
        min_yr (int): Minimum year to fetch albums for.
        max_yr (int): Maximum year to fetch albums for.
        mrkt (str): Spotify market (e.g., "US").
    """
    def get_access_token():
        """Obtain an access token using Spotify Client Credentials Flow."""
        url = "https://accounts.spotify.com/api/token"
        headers = {
            "Authorization": "Basic " + base64.b64encode(f"{CLIENT_ID}:{CLIENT_SECRET}".encode()).decode()
        }
        data = {"grant_type": "client_credentials"}
        response = requests.post(url, headers=headers, data=data)
        return response.json().get("access_token")

    def fetch_albums_by_years(limit, min_yr, max_yr, mrkt):
        """Fetch albums by year range from Spotify with dynamic pagination."""
        access_token = get_access_token()
        all_albums = []

        # Enforce Spotify's query limit of 1,000 albums per query
        if limit > 1000:
            raise ValueError("Spotify API limits queries to 1,000 results per year.")

        for year in range(min_yr, max_yr + 1):
            print(f"Fetching up to {limit} albums for the year {year}...")
            offset = 0
            albums_fetched = 0

            while albums_fetched < limit:
                batch_limit = min(limit - albums_fetched, 50)  # Spotify allows up to 50 results per request
                url = "https://api.spotify.com/v1/search"
                headers = {"Authorization": f"Bearer {access_token}"}
                params = {
                    "q": f"year:{year}",
                    "type": "album",
                    "limit": batch_limit,
                    "offset": offset,
                    "market": mrkt
                }
                response = requests.get(url, headers=headers, params=params)
                if response.status_code != 200:
                    print(f"Failed to fetch albums for {year}: {response.status_code} - {response.text}")
                    break

                albums = response.json().get('albums', {}).get('items', [])
                if not albums:
                    break  # No more albums to fetch

                for album in albums:
                    album_name = album.get('name', 'Unknown Album')
                    artist_name = album.get('artists', [{}])[0].get('name', 'Unknown Artist')
                    all_albums.append((album_name, artist_name, year))
                    albums_fetched += 1

                offset += batch_limit  # Update offset for the next batch

                # Exit loop early if we've fetched the requested number of albums
                if albums_fetched >= limit:
                    break

        return all_albums

    def get_all_versions(base_url, master_id, headers):
        """Get all versions of a master release from Discogs."""
        if not master_id:
            return []
        versions_url = f"{base_url}/masters/{master_id}/versions"
        versions_response = requests.get(versions_url, headers=headers)
        return versions_response.json().get('versions', [])

    def get_recording_studios(album_list, discogs_token):
        """Fetch recording studios for albums using the Discogs API."""
        headers = {
            'Authorization': f'Discogs token={discogs_token}',
            'User-Agent': user_agent
        }
        base_url = 'https://api.discogs.com'
        releases = []

        print("Starting to process albums...")

        for index, (album_name, artist_name, year) in enumerate(album_list, 1):
            print(f"\nChecking [{index}]: {artist_name} - {album_name} ({year})")
            search_url = f"{base_url}/database/search"
            params = {'q': album_name, 'artist': artist_name, 'type': 'release'}
            search_response = requests.get(search_url, headers=headers, params=params)
            search_results = search_response.json()
            if not search_results.get('results'):
                print(f"No results found on Discogs for: {album_name} by {artist_name}")
                continue

            release_id = search_results['results'][0].get('id')
            release_url = f"{base_url}/releases/{release_id}"
            time.sleep(1)  # Respect rate limits
            release_response = requests.get(release_url, headers=headers)
            release_data = release_response.json()

            recording_studios = set()
            master_id = release_data.get('master_id')

            if master_id:
                master_url = f"{base_url}/masters/{master_id}"
                master_response = requests.get(master_url, headers=headers)
                master_data = master_response.json()
                for company in master_data.get('companies', []):
                    if company.get('entity_type_name') == 'Recorded At':
                        recording_studios.add(company.get('name', ''))

                versions = get_all_versions(base_url, master_id, headers)
                for version in versions:
                    version_id = version.get('id')
                    version_url = f"{base_url}/releases/{version_id}"
                    time.sleep(1)
                    version_response = requests.get(version_url, headers=headers)
                    version_data = version_response.json()
                    for company in version_data.get('companies', []):
                        if company.get('entity_type_name') == 'Recorded At':
                            recording_studios.add(company.get('name', ''))

            for company in release_data.get('companies', []):
                if company.get('entity_type_name') == 'Recorded At':
                    recording_studios.add(company.get('name', ''))

            releases.append({
                'artist': artist_name,
                'album_name': album_name,
                'recorded_at': '; '.join(sorted(recording_studios)) if recording_studios else 'Not specified',
                'year': year
            })

        output_file = f'top_album_studios_{min_yr}_{max_yr}.csv'
        with open(output_file, 'w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=['artist', 'album_name', 'recorded_at', 'year'])
            writer.writeheader()
            writer.writerows(releases)

        print(f"\nData successfully exported to {output_file}")
        return output_file

    # Fetch albums from Spotify
    albums = fetch_albums_by_years(limit, min_yr, max_yr, mrkt)

    # Fetch recording studios from Discogs and export to CSV
    return get_recording_studios(albums, discogs_token)

# %%
top_album_studios(300, 2019, 2019, "US")

# %%
import requests
import os
import base64
import csv
import time
from datetime import datetime
from dotenv import load_dotenv
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# Load environment variables from .env file
load_dotenv()

# Spotify API credentials
CLIENT_ID = os.getenv('CLIENT_ID')
CLIENT_SECRET = os.getenv('CLIENT_SECRET')

# Discogs API credentials
discogs_token = os.getenv('discogs_token')
user_agent = os.getenv('USER_AGENT')

# Validate credentials
if not CLIENT_ID or not CLIENT_SECRET or not discogs_token or not user_agent:
    raise ValueError("API credentials or User-Agent are missing! Please check your .env file.")

# Configure retry strategy
def create_session():
    session = requests.Session()
    retries = Retry(
        total=5,  # number of retries
        backoff_factor=1,  # wait 1, 2, 4, 8, 16 seconds between retries
        status_forcelist=[429, 500, 502, 503, 504]  # HTTP status codes to retry on
    )
    session.mount('https://', HTTPAdapter(max_retries=retries))
    return session

def make_discogs_request(url, headers, params=None):
    """Make a request to Discogs API with rate limiting handling"""
    session = create_session()
    try:
        response = session.get(url, headers=headers, params=params)
        
        # Check rate limiting headers
        remaining = int(response.headers.get('X-Discogs-Ratelimit-Remaining', 0))
        
        # If we're running low on requests, wait longer
        if remaining < 10:
            time.sleep(3)  # Wait 3 seconds when close to limit
        else:
            time.sleep(1)  # Standard 1 second wait
            
        if response.status_code == 429:
            retry_after = int(response.headers.get('Retry-After', 60))
            print(f"Rate limited. Waiting {retry_after} seconds...")
            time.sleep(retry_after)
            return make_discogs_request(url, headers, params)
            
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error making request to {url}: {str(e)}")
        return None

def top_album_studios(limit, min_yr, max_yr, mrkt):
    """
    Fetch top albums from Spotify and retrieve their recording studios from Discogs.
    Results are saved to a CSV file.
    """
    def get_access_token():
        """Obtain an access token using Spotify Client Credentials Flow."""
        session = create_session()
        url = "https://accounts.spotify.com/api/token"
        headers = {
            "Authorization": "Basic " + base64.b64encode(f"{CLIENT_ID}:{CLIENT_SECRET}".encode()).decode()
        }
        data = {"grant_type": "client_credentials"}
        response = session.post(url, headers=headers, data=data)
        return response.json().get("access_token")

    def fetch_albums_by_years(limit, min_yr, max_yr, mrkt):
        """Fetch albums by year range from Spotify with dynamic pagination."""
        session = create_session()
        access_token = get_access_token()
        all_albums = []

        if limit > 1000:
            raise ValueError("Spotify API limits queries to 1,000 results per year.")

        for year in range(min_yr, max_yr + 1):
            print(f"Fetching up to {limit} albums for {year}...")
            offset = 0
            albums_fetched = 0

            while albums_fetched < limit:
                batch_limit = min(limit - albums_fetched, 50)
                url = "https://api.spotify.com/v1/search"
                headers = {"Authorization": f"Bearer {access_token}"}
                params = {
                    "q": f"year:{year}",
                    "type": "album",
                    "limit": batch_limit,
                    "offset": offset,
                    "market": mrkt
                }
                
                try:
                    response = session.get(url, headers=headers, params=params)
                    response.raise_for_status()
                    data = response.json()
                    
                    albums = data.get('albums', {}).get('items', [])
                    if not albums:
                        break

                    for album in albums:
                        album_name = album.get('name', 'Unknown Album')
                        artist_name = album.get('artists', [{}])[0].get('name', 'Unknown Artist')
                        all_albums.append((album_name, artist_name, year))
                        albums_fetched += 1

                    offset += batch_limit
                    
                    if albums_fetched >= limit:
                        break
                        
                    time.sleep(1)  # Rate limiting for Spotify
                    
                except requests.exceptions.RequestException as e:
                    print(f"Error fetching albums for {year}: {str(e)}")
                    break

        return all_albums

    def get_all_versions(base_url, master_id, headers):
        """Get all versions of a master release from Discogs."""
        if not master_id:
            return []
        versions_url = f"{base_url}/masters/{master_id}/versions"
        return make_discogs_request(versions_url, headers, {}).get('versions', [])

    def get_recording_studios(album_list, discogs_token):
        """Fetch recording studios for albums using the Discogs API."""
        headers = {
            'Authorization': f'Discogs token={discogs_token}',
            'User-Agent': user_agent
        }
        base_url = 'https://api.discogs.com'
        releases = []

        print("Starting to process albums...")

        for index, (album_name, artist_name, year) in enumerate(album_list, 1):
            print(f"\nChecking [{index}]: {artist_name} - {album_name} ({year})")
            
            # Search for release
            search_url = f"{base_url}/database/search"
            params = {'q': album_name, 'artist': artist_name, 'type': 'release'}
            search_results = make_discogs_request(search_url, headers, params)
            
            if not search_results or not search_results.get('results'):
                print(f"No results found on Discogs for: {album_name} by {artist_name}")
                continue

            release_id = search_results['results'][0].get('id')
            release_url = f"{base_url}/releases/{release_id}"
            release_data = make_discogs_request(release_url, headers)
            
            if not release_data:
                continue

            recording_studios = set()
            master_id = release_data.get('master_id')

            if master_id:
                master_url = f"{base_url}/masters/{master_id}"
                master_data = make_discogs_request(master_url, headers)
                
                if master_data:
                    for company in master_data.get('companies', []):
                        if company.get('entity_type_name') == 'Recorded At':
                            recording_studios.add(company.get('name', ''))

                    versions = get_all_versions(base_url, master_id, headers)
                    for version in versions:
                        version_id = version.get('id')
                        version_url = f"{base_url}/releases/{version_id}"
                        version_data = make_discogs_request(version_url, headers)
                        
                        if version_data:
                            for company in version_data.get('companies', []):
                                if company.get('entity_type_name') == 'Recorded At':
                                    recording_studios.add(company.get('name', ''))

            for company in release_data.get('companies', []):
                if company.get('entity_type_name') == 'Recorded At':
                    recording_studios.add(company.get('name', ''))

            releases.append({
                'artist': artist_name,
                'album_name': album_name,
                'recorded_at': '; '.join(sorted(recording_studios)) if recording_studios else 'Not specified',
                'year': year
            })

        output_file = f'top_album_studios_{min_yr}_{max_yr}.csv'
        with open(output_file, 'w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=['artist', 'album_name', 'recorded_at', 'year'])
            writer.writeheader()
            writer.writerows(releases)

        print(f"\nData successfully exported to {output_file}")
        return output_file

    albums = fetch_albums_by_years(limit, min_yr, max_yr, mrkt)
    return get_recording_studios(albums, discogs_token)

# %%
top_album_studios(300, 2020, 2021, "US")

# %%
import requests
import os
import base64
import csv
import time
from datetime import datetime
import concurrent.futures
from functools import lru_cache
from typing import Dict, List, Set, Optional
from dotenv import load_dotenv
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# Load environment variables from .env file
load_dotenv()

# Spotify API credentials
CLIENT_ID = os.getenv('CLIENT_ID')
CLIENT_SECRET = os.getenv('CLIENT_SECRET')
discogs_token = os.getenv('discogs_token')
user_agent = os.getenv('USER_AGENT')

# Validate credentials
if not CLIENT_ID or not CLIENT_SECRET or not discogs_token or not user_agent:
    raise ValueError("API credentials or User-Agent are missing! Please check your .env file.")

# Configure session with connection pooling
session = requests.Session()
retries = Retry(
    total=5,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504]
)
adapter = HTTPAdapter(
    max_retries=retries,
    pool_connections=20,  # Increase connection pool size
    pool_maxsize=20
)
session.mount('https://', adapter)

# Cache for API responses
@lru_cache(maxsize=1000)
def cached_discogs_request(url: str, token: str) -> Optional[Dict]:
    """Cache Discogs API responses to avoid duplicate requests"""
    headers = {
        'Authorization': f'Discogs token={token}',
        'User-Agent': user_agent
    }
    try:
        response = session.get(url, headers=headers)
        remaining = int(response.headers.get('X-Discogs-Ratelimit-Remaining', 0))
        
        if remaining < 5:
            time.sleep(2)
        
        if response.status_code == 429:
            time.sleep(int(response.headers.get('Retry-After', 60)))
            return cached_discogs_request(url, token)
            
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException:
        return None

def get_spotify_access_token() -> str:
    """Get Spotify access token with caching"""
    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": "Basic " + base64.b64encode(f"{CLIENT_ID}:{CLIENT_SECRET}".encode()).decode()
    }
    data = {"grant_type": "client_credentials"}
    response = session.post(url, headers=headers, data=data)
    return response.json().get("access_token")

def fetch_spotify_albums(year: int, limit: int, offset: int, access_token: str, market: str) -> List:
    """Fetch a batch of albums from Spotify"""
    url = "https://api.spotify.com/v1/search"
    headers = {"Authorization": f"Bearer {access_token}"}
    params = {
        "q": f"year:{year}",
        "type": "album",
        "limit": min(limit, 50),
        "offset": offset,
        "market": market
    }
    
    response = session.get(url, headers=headers, params=params)
    response.raise_for_status()
    return response.json().get('albums', {}).get('items', [])

def process_album(album_data: tuple) -> Dict:
    """Process a single album to find recording studios"""
    album_name, artist_name, year = album_data
    base_url = 'https://api.discogs.com'
    recording_studios = set()
    
    # Search for release
    search_url = f"{base_url}/database/search"
    params = {'q': f"{album_name} {artist_name}", 'type': 'release'}
    search_results = cached_discogs_request(f"{search_url}?{requests.compat.urlencode(params)}", discogs_token)
    
    if not search_results or not search_results.get('results'):
        return {
            'artist': artist_name,
            'album_name': album_name,
            'recorded_at': 'Not found',
            'year': year
        }

    # Process first 3 most relevant results instead of just the first one
    for result in search_results['results'][:3]:
        release_id = result.get('id')
        release_data = cached_discogs_request(f"{base_url}/releases/{release_id}", discogs_token)
        
        if not release_data:
            continue

        # Extract studios from release
        for company in release_data.get('companies', []):
            if company.get('entity_type_name') == 'Recorded At':
                recording_studios.add(company.get('name', ''))

        # Check master release if exists
        master_id = release_data.get('master_id')
        if master_id:
            master_data = cached_discogs_request(f"{base_url}/masters/{master_id}", discogs_token)
            if master_data:
                for company in master_data.get('companies', []):
                    if company.get('entity_type_name') == 'Recorded At':
                        recording_studios.add(company.get('name', ''))

    return {
        'artist': artist_name,
        'album_name': album_name,
        'recorded_at': '; '.join(sorted(recording_studios)) if recording_studios else 'Not specified',
        'year': year
    }

def top_album_studios(limit: int, min_yr: int, max_yr: int, mrkt: str) -> str:
    """Main function to fetch albums and their recording studios"""
    all_albums = []
    access_token = get_spotify_access_token()
    
    # Fetch albums from Spotify
    for year in range(min_yr, max_yr + 1):
        print(f"Fetching albums for {year}...")
        offset = 0
        while len(all_albums) < limit:
            batch = fetch_spotify_albums(year, min(50, limit - len(all_albums)), offset, access_token, mrkt)
            if not batch:
                break
                
            all_albums.extend([
                (album.get('name', 'Unknown Album'),
                 album.get('artists', [{}])[0].get('name', 'Unknown Artist'),
                 year)
                for album in batch
            ])
            offset += len(batch)
            time.sleep(0.5)  # Reduced sleep time for Spotify API
    
    # Process albums in parallel
    results = []
    with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
        future_to_album = {executor.submit(process_album, album): album for album in all_albums}
        for future in concurrent.futures.as_completed(future_to_album):
            album = future_to_album[future]
            try:
                result = future.result()
                results.append(result)
                print(f"Processed: {result['artist']} - {result['album_name']}")
            except Exception as e:
                print(f"Error processing {album}: {str(e)}")
    
    # Write results to CSV
    output_file = f'top_album_studios_{min_yr}_{max_yr}.csv'
    with open(output_file, 'w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['artist', 'album_name', 'recorded_at', 'year'])
        writer.writeheader()
        writer.writerows(results)
    
    return output_file

# %%
# Example usage
result_file = top_album_studios(limit=900, min_yr=2022,max_yr=2024,mrkt='US')
# Out:
# Fetching albums for 2022...
# Fetching albums for 2023...
# Fetching albums for 2024...
# Processed: Metro Boomin - HEROES & VILLAINS
# Processed: Zach Bryan - American Heartbreak
# Processed: SZA - SOS
# Processed: Bad Bunny - Un Verano Sin Ti
# Processed: Noah Kahan - Stick Season
# Processed: Harry Styles - Harry's House
# Processed: SZA - SOS
# Processed: Taylor Swift - Midnights
# Processed: Sabrina Carpenter - emails i can't send
# Processed: Kendrick Lamar - Mr. Morale & The Big Steppers
# Processed: Drake - Her Loss
# Processed: Juice WRLD - Fighting Demons (Deluxe)
# Processed: Milli Hughes - Deep Phase Noise
# Processed: beabadoobee - Beatopia
# Processed: Future - I NEVER LIKED YOU
# Processed: Brent Faiyaz - WASTELAND
# Processed: Zach Bryan - Something in the Orange
# Processed: Zach Bryan - Summertime Blues
# Processed: Steve Lacy - Gemini Rights
# Processed: $uicideboy$ - Sing Me a Lullaby, My Sweet Temptation
# Processed: Laufey - Everything I Know About Love
# Processed: Djo - DECIDE
# Processed: Various Artists - 100 Greatest Christmas Songs Ever
# Processed: Conan Gray - Superache
# Processed: The Red Clay Strays - Moment of Truth
# Processed: Lainey Wilson - Bell Bottom Country
# Processed: Luke Combs - Growin' Up
# Processed: Bad Omens - THE DEATH OF PEACE OF MIND
# Processed: sign crushes motorist - i'll be okay
# Processed: Montell Fish - JAMIE
# Processed: The Weeknd - Dawn FM
# Processed: d4vd - Romantic Homicide
# Processed: Lizzy McAlpine - five seconds flat
# Processed: Drake - Honestly, Nevermind
# Processed: Taylor Swift - Midnights (3am Edition)
# Processed: Zach Bryan - Burn, Burn, Burn
# Processed: JID - The Forever Story (Extended Version)
# Processed: Josh Meloy - Porch Light
# Processed: Imagine Dragons - Mercury - Acts 1 & 2
# Processed: Tate McRae - i used to think i could fly
# Processed: SZA - Ctrl (Deluxe)
# Processed: Thee Sacred Souls - Thee Sacred Souls
# Processed: Beyoncé - RENAISSANCE
# Processed: Billie Eilish - Guitar Songs
# Processed: Gunna - DS4EVER
# Processed: Yeat - Lyfë
# Processed: Montell Fish - Her Love Still Haunts Me Like a Ghost
# Processed: Ivan Cornejo - Dañado
# Processed: Feid - FELIZ CUMPLEAÑOS FERXXO TE PIRATEAMOS EL ÁLBUM
# Processed: Junior H - Mi Vida En Un Cigarro 2
# Processed: JVKE - this is what ____ feels like (Vol. 1-4)
# Processed: Bryan Martin - Self Inflicted Scars
# Processed: Suki Waterhouse - Good Looking
# Processed: Lil Baby - It's Only Me
# Processed: Joji - SMITHEREENS
# Processed: Ethel Cain - Preacher’s Daughter
# Processed: Ken Carson - X
# Processed: Rod Wave - Beautiful Mind
# Processed: The 1975 - Being Funny In A Foreign Language
# Processed: Fuerza Regida - Pa Que Hablen
# Processed: Post Malone - Twelve Carat Toothache
# Processed: LUCKI - FLAWLESS LIKE ME
# Processed: Omar Apollo - Ivory
# Processed: Øneheart - snowfall
# Processed: Eslabon Armado - NOSTALGIA
# Processed: Wyatt Flores - Please Don't Go
# Processed: Jack Harlow - Come Home The Kids Miss You
# Processed: BoyWithUke - Serotonin Dreams
# Processed: Yeat - 2 Alivë
# Processed: Lil Durk - 7220 (Reloaded)
# Processed: Benson Boone - Walk Me Home...
# Processed: Destroy Lonely - NO STYLIST
# Processed: Mac Miller - I Love Life, Thank You
# Processed: Giveon - Give Or Take
# Processed: Warren Zeiders - 717 Tapes the Album
# Processed: Take Care - Agony
# Processed: Nursery Rhymes ABC - Baby Lullabies with Soothing Night-time Sounds
# Processed: David Kushner - Footprints I Found
# Processed: Jon Pardi - Mr. Saturday Night
# Processed: Frou Frou - A New Kind Of Love (Demo)
# Processed: Caamp - Lavender Days
# Processed: Dylan Scott - Livin' My Best Life
# Processed: Megan Thee Stallion - Traumazine
# Processed: NewJeans - NewJeans 1st EP 'New Jeans'
# Processed: David Guetta - I'm Good (Blue)
# Processed: Shaboozey - Cowboys Live Forever, Outlaws Never Die
# Processed: Evan Honer - Jersey Giant
# Processed: ERNEST - FLOWER SHOPS (THE ALBUM)
# Processed: Ivan Cornejo - Dañado (Deluxe)
# Processed: Sabrina Carpenter - A Nonsense Christmas
# Processed: Kane Brown - Different Man
# Processed: mgk - mainstream sellout
# Processed: LUCKI - New Drank
# Processed: Henry Janzen - Cozy Christmas by the Fireplace
# Processed: Kodak Black - Back For Everything
# Processed: Rio Romeo - Good God!
# Processed: Sonder - Too Late To Die Young
# Processed: Teddy Swims - Sleep is Exhausting
# Processed: Royel Otis - Oysters In My Pocket
# Processed: LECADE - When Im Gone
# Processed: keshi - GABRIEL
# Processed: Cults - Offering
# Processed: Mariah the Scientist - Buckles Laboratories Presents: The Intermission
# Processed: ThxSoMch - SPIT IN MY FACE!
# Processed: Isabel LaRosa - i'm yours
# Processed: Cole Swindell - Stereotype
# Processed: YoungBoy Never Broke Again - The Last Slimeto
# Processed: BTS - Proof
# Processed: Birth Day - Boyhood
# Processed: Molecualar Binary - Fuori Zona
# Processed: Xavier Wulf - Blood Shore Season 3
# Processed: Real Boston Richey - Public Housing
# Processed: Key Glock - PRE5L
# Processed: La Santa Grifa - Fuera de Órbita
# Processed: Swedish House Mafia - Paradise Again
# Processed: Stephen Sanchez - Easy On My Eyes
# Processed: Motionless In White - Scoring The End Of The World
# Processed: Meghan Trainor - Takin' It Back
# Processed: Miracle Tones - Anxiety Relief
# Processed: Anne Wilson - My Jesus
# Processed: Ken Carson - XTENDED
# Processed: Dustin Lynch - Blue In The Sky
# Processed: YoungBoy Never Broke Again - Colors
# Processed: Sean Paul - Dutty Rock (20th Anniversary)
# Processed: Macabre Plaza - Out With the Old in With the Taboo
# Processed: Spiritual Frequencies - 528 Hz Miracle Transformation
# Processed: 49 Winchester - Fortune Favors the Bold
# Processed: Chance Peña - In My Room
# Processed: King Von - What It Means To Be King
# Processed: Elevation Worship - LION
# Processed: $uicideboy$ - DIRTIESTNASTIEST$UICIDE
# Processed: Julión Álvarez y su Norteño Banda - De Hoy En Adelante, Que Te Vaya Bien
# Processed: Pure Relaxing Vibes - Rain and Thunder
# Processed: Stray Kids - SKZ-REPLAY
# Processed: Baby Keem - The Melodic Blue (Deluxe)
# Processed: XXXTENTACION - LOOK AT ME: THE ALBUM
# Processed: Misa Bee - Noise Waterfalls
# Processed: Quavo - Only Built For Infinity Links
# Processed: Henry Janzen - Extra Cozy Christmas Holiday Special
# Processed: GloRilla - Anyways, Life’s Great…
# Processed: Natura Ferox - Gentle White Noise
# Processed: Louis Armstrong - Louis Wishes You a Cool Yule
# Processed: Alfredo Olivas - ALFA & OMEGA
# Processed: Big Thief - Dragon New Warm Mountain I Believe In You
# Processed: I Prevail - TRUE POWER
# Processed: OneRepublic - I Ain’t Worried (Music From The Motion Picture "Top Gun: Maverick")
# Processed: Mike Dimes - IN DIMES WE TRUST
# Processed: Chase Shakur - It'll Be Fine
# Processed: Hermanos Espinoza - HNOS ESPINOZA, Vol. 4
# Processed: Josiah and the Bonnevilles - 2022
# Processed: Tyler Childers - Can I Take My Hounds to Heaven?
# Processed: Reneé Rapp - Everything To Everyone
# Processed: Romeo Santos - Fórmula, Vol. 3
# Processed: Zach Top - Zach Top
# Processed: Van Vogel Ensemble - Instrumental Christmas - Piano & Strings
# Processed: Lil Durk - 7220
# Processed: jaydes - romanticism
# Processed: Fuerza Regida - Sigan Hablando
# Processed: Laufey - Everything I Know About Love
# Processed: Smino - Luv 4 Rent
# Processed: Stick Figure - Wisdom
# Processed: Walker Hayes - Country Stuff The Album
# Processed: Hermanos Espinoza - Prueba De Fuego
# Processed: Koe Wetzel - Hell Paso
# Processed: Σtella - Up and Away
# Processed: Denzel Curry - Melt My Eyez See Your Future
# Processed: Rain Fruits Sounds - Gentle Night Rain
# Processed: Henry Janzen - Extra Cozy Christmas Holiday Special, Vol. 2
# Processed: Future - I NEVER LIKED YOU
# Processed: Suki Waterhouse - I Can't Let Go
# Processed: Steven Rodriguez - Shackles
# Processed: Dhruv - rapunzel
# Processed: Shinedown - Planet Zero
# Processed: Mother Mother - Inside (Deluxe)
# Processed: House Of Pain - House of Pain (Fine Malt Lyrics) [30 Years] [Deluxe Edition]
# Processed: Bailey Zimmerman - Leave The Light On
# Processed: Muni Long - Public Displays Of Affection: The Album
# Processed: Miracle Tones - 777 Hz Attract Positivity
# Processed: Rema - Calm Down (with Selena Gomez)
# Processed: David Schultz - Christmas Piano (Vol. 4)
# Processed: Silent Rhythm - Ultra Relaxing Music for Sleep
# Processed: Taylor Swift - Midnights (3am Edition)
# Processed: Rex Orange County - WHO CARES?
# Processed: El Alfa - SAGITARIO
# Processed: TobyMac - Life After Death
# Processed: Lil Wayne - Sorry 4 The Wait
# Processed: Kelsea Ballerini - SUBJECT TO CHANGE
# Processed: Mora - MICRODOSIS
# Processed: Destroy Lonely - NS+ (ULTRA)
# Processed: SleazyWorld Go - Where The Shooters Be
# Processed: Mitski - Laurel Hell
# Processed: Stray Kids - ODDINARY
# Processed: Cris Mj - Una Noche en Medellín
# Processed: The Backseat Lovers - Waiting to Spill
# Processed: Luis R Conriquez - El Gavilán
# Processed: Yeat - 2 Alivë (Geëk Pack)
# Processed: Kanye West - True Love
# Processed: That Mexican OT - Nonsense and Mexican Shit
# Processed: Take Care - Reject
# Processed: Joey Bada$$ - 2000
# Processed: Junior H - CONTINGENTE
# Processed: Zach Bryan - The Greatest Day of My Life
# Processed: Tory Lanez - Sorry 4 What
# Processed: Jane Color - Relaxing Brown Noise 256 Hz
# Processed: Alec Benjamin - (Un)Commentary
# Processed: Zach Bryan - All My Homies Hate Ticketmaster (Live from Red Rocks)
# Processed: Yatta Bandz - Perfect Storm
# Processed: Evomin - White Noise Comfort
# Processed: Yuridia - Pa' Luego Es Tarde
# Processed: Midrift - Midrift
# Processed: Tory Lanez - I LIKE
# Processed: Nessa Barrett - young forever
# Processed: Yung Gravy - Marvelous
# Processed: Nardo Wick - Who is Nardo Wick?? (Deluxe)
# Processed: Ghost - IMPERA
# Processed: Dutch Melrose - RUNRUNRUN
# Processed: Nickelback - Get Rollin'
# Processed: Freddie Dredd - Freddie's Inferno
# Processed: Summrs - FALLEN RAVEN
# Processed: Kyle Mendes Jazz Trio - I'll Be Home For Christmas
# Processed: Pity Party (Girls Club) - Hard Times / Bad Trips
# Processed: Baby Smoove - Im Still Serious 2
# Processed: Pentatonix - Holidays Around the World
# Processed: Kameron Marlowe - We Were Cowboys
# Processed: Lizzo - Special
# Processed: Feid - SIXDO
# Processed: Avenoir - Shameless
# Processed: Jon Reddick - God, Turn It Around
# Processed: Norah Jones - I Dream Of Christmas (Deluxe)
# Processed: Fred again.. - Actual Life 3 (January 1 - September 9 2022)
# Processed: Fleshwater - We're Not Here to Be Loved
# Processed: Drugdealer - Hiding in Plain Sight
# Processed: Edgardo Nuñez - Billete Grande (En Vivo)
# Processed: Hovar - Lean Noise
# Processed: Hotel Ugly - I Think I Left the Stove On
# Processed: Mentatranque - White Dreams
# Processed: Becky G - ESQUEMAS
# Processed: ROSALÍA - MOTOMAMI
# Processed: Aaron May - No Recognition
# Processed: NewJeans - Ditto
# Processed: RAYE - Escapism.
# Processed: Josh Meloy - You Here Tonight
# Processed: Hotel Ugly - Shut up My Moms Calling (Sped up)
# Processed: Ado - Kyougen
# Processed: Miracle Tones - 888 Hz Abundance Gate
# Processed: Wyatt Flores - Losing Sleep
# Processed: Mt. Joy - Orange Blood
# Processed: jaydes - heartpacing
# Processed: Will Wood - "In case I make it,"
# Processed: BLACKPINK - BORN PINK
# Processed: 42 Dugg - Last Ones Left
# Processed: Frankie Ruiz - Feliz Navidad Con Salsa
# Processed: Paul Moretti Trio - Happy Christmas, Little Friend
# Processed: Aileron - Sonorous Dream
# Processed: Dayseeker - Dark Sun
# Processed: Polyphia - Remember That You Will Die
# Processed: Five Finger Death Punch - AfterLife
# Processed: Whiskey Myers - Tornillo
# Processed: Lil Uzi Vert - Just Wanna Rock
# Processed: jev. - the color grey.
# Processed: Dean Lewis - The Hardest Love
# Processed: Panoramia - Tranquil White Noise
# Processed: Sonic The Hedgehog - Sonic Frontiers Original Soundtrack Stillness & Motion
# Processed: We Came As Romans - Darkbloom
# Processed: Ado - UTA'S SONGS ONE PIECE FILM RED
# Processed: RM - Indigo
# Processed: Mike Sherm - Ballin
# Processed: Banda MS de Sergio Lizárraga - Ojos Cerrados
# Processed: JVKE - this is what falling in love feels like (554Hz)
# Processed: Austin Tolliver - Ride 4 Me
# Processed: Stephen Sanchez - Until I Found You (Em Beihold Version)
# Processed: Steve Lacy - Bad Habit
# Processed: AURORA - The Gods We Can Touch
# Processed: Florence + The Machine - Dance Fever
# Processed: Khruangbin - Texas Moon
# Processed: Doja Cat - Vegas (From the Original Motion Picture Soundtrack ELVIS)
# Processed: Chance Peña - Sleep Deprivation
# Processed: HYBS - Making Steak
# Processed: VOILÀ - Happy Never After
# Processed: Nylana - Velara (Ambient Noise)
# Processed: RSCL - Lost
# Processed: Klangspiel - Peaceful Flow of White Noise
# Processed: NLE Choppa - SLUT ME OUT
# Processed: Nursery Rhymes ABC - Classical Baby : Classical Lullabies for Babies
# Processed: Brantley Gilbert - So Help Me God
# Processed: Silent Rhythm - Deep Low Frequencies for Sleeping
# Processed: Edicion Especial - Quédate Conmigo
# Processed: mage tears - cats in the cold
# Processed: brakence - hypochondriac
# Processed: Christian Nodal - Forajido EP 1
# Processed: Sam Smith - Unholy (feat. Kim Petras)
# Processed: Anuel AA - LLNM2
# Processed: Stray Kids - MAXIDENT
# Processed: saraunh0ly - wutiwant
# Processed: Ardeon - Ruido Blanco
# Processed: Omah Lay - Boy Alone
# Processed: Marshmello - Numb
# Processed: Charlie Puth - CHARLIE
# Processed: 5 Seconds of Summer - 5SOS5
# Processed: Riley Green - Hell Of A Way To Go
# Processed: Charli xcx - CRASH
# Processed: Papa Roach - Ego Trip
# Processed: Little Starflower - Quiet Moments
# Processed: Sebastian Yatra - Dharma
# Processed: Focus Noise - Fluffy Winds
# Processed: Tate McRae - uh oh
# Processed: Thomas Rhett - Merry Christmas, Y’all
# Processed: BLACKPINK - BORN PINK
# Processed: Van Vogel Ensemble - Instrumental Christmas - Piano & Strings (Vol. 2)
# Processed: Ozuna - OzuTochi
# Processed: Gucci Mane - So Icy Gang: The ReUp
# Processed: bbno$ - bag or die
# Processed: Junior H - El Hijo Mayor
# Processed: Post Malone - Cooped Up / Return Of The Mack
# Processed: Ambi Val - Noise For Relaxation
# Processed: Atmosphere of Calm - White Noise Sleeping Pill
# Processed: Bob Sinclar - World, Hold On (FISHER Rework)
# Processed: Riton - Fake ID (Coke & Rum Remix)
# Processed: Vince Guaraldi Trio - A Charlie Brown Christmas (Super Deluxe Edition)
# Processed: ODESZA - The Last Goodbye
# Processed: Los Farmerz - Hublot
# Processed: Lil Durk - 7220 (Deluxe)
# Processed: ROSALÍA - MOTOMAMI +
# Processed: Valdervande - Out Cold with White Noise
# Processed: Avenoir - TMW
# Processed: Alex Isley - Marigold
# Processed: Ken Carson - Teen Bean
# Processed: DJ Khaled - GOD DID
# Processed: Wild Rivers - Sidelines
# Processed: Parker Jack - CRY
# Processed: Delaney Bailey - (i would have followed you)
# Processed: Barry Snyder Band - It's Christmas Jazz Time
# Processed: CoComelon - Nursery Rhymes by CoComelon Vol.2
# Processed: Ahzura - Green Energy
# Processed: for KING & COUNTRY - What Are We Waiting For?
# Processed: Irvin Smith - Frosty The Snowman
# Processed: Bizarrap - Quevedo: Bzrp Music Sessions, Vol. 52
# Processed: Homixide Gang - Homixide Lifestyle
# Processed: sweet planet - first light
# Processed: Alok - Deep Down (feat. Never Dull)
# Processed: Thomas Rhett - Where We Started
# Processed: Sadie Jean - Locksmith
# Processed: Fireboy DML - Playboy
# Processed: Ella Mai - Heart On My Sleeve
# Processed: Jackson Dean - Greenbroke
# Processed: Jim Efforts - The Wavy White Noise
# Processed: LF SYSTEM - Afraid To Feel
# Processed: A Boogie Wit da Hoodie - Me vs. Myself
# Processed: SEVENTEEN - SEVENTEEN 4th Album 'Face the Sun'
# Processed: Ari Abdul - BABYDOLL
# Processed: Sueco - It Was Fun While It Lasted
# Processed: The White Noise Travelers - White Noise Flakes
# Processed: Lyla Lee Band - Winter Wonderland
# Processed: Em Beihold - Egg in the Backseat
# Processed: Pure Sleeping Vibes - Under Nocturnal Clouds
# Processed: SugarHill Keem - KING OF DRILL
# Processed: Eli Starr Trio - Happy Christmas
# Processed: Sub Urban - HIVE
# Processed: Asake - Mr. Money With The Vibe
# Processed: XXXTENTACION - vice city
# Processed: mgk - lockdown sessions
# Processed: Nikolai Tal - Ghibli Lullabies
# Processed: Gibran Alcocer - Idea 10
# Processed: Three Days Grace - EXPLOSIONS
# Processed: The Clear Mind - White Noise Cave
# Processed: Wet Leg - Wet Leg
# Processed: The Lumineers - BRIGHTSIDE
# Processed: Natanael Cano - NataKong
# Processed: Benson Boone - Before You
# Processed: Daddy Yankee - LEGENDADDY
# Processed: Teddy Swims - Tough Love
# Processed: The Simps - Siblings
# Processed: Sam Barber - Ramblin Man
# Processed: El Chachito - En Paris
# Processed: Cordae - From a Birds Eye View
# Processed: quannnic - kenopsia
# Processed: Burna Boy - Love, Damini
# Processed: Dreamville - D-Day: A Gangsta Grillz Mixtape
# Processed: Matt Hansen - better off without me
# Processed: Los Gemelos De Sinaloa - No Le Aflojo
# Processed: Static Harmony - Doze Off
# Processed: Øneheart - this feeling
# Processed: Kim Petras - Slut Pop
# Processed: Depeche Mode - Violator | The 12" Singles
# Processed: Morgan Wallen - You Proof
# Processed: Fall Asleep Machine - Full Focus
# Processed: daniel.mp3 - green to blue (slowed + reverbed)
# Processed: Soft Soundscapes - Sanfter Regen
# Processed: Kordhell - Murder In My Mind
# Processed: Lorna Shore - Pain Remains
# Processed: Grupo Frontera - En Vivo, Vol.1
# Processed: Central Cee - Doja
# Processed: Benson Boone - In The Stars
# Processed: Luis Mexia - Haciendo Lo Mío
# Processed: Kid Cudi - Entergalactic
# Processed: Chase Atlantic - BEAUTY IN DEATH (DELUXE EDITION)
# Processed: Jay Wheeler - Emociones
# Processed: The Slumbering One - It's Raining
# Processed: Juice WRLD - In My Head
# Processed: Benny Friedman - It Sounds Like Chanukah
# Processed: FKA twigs - CAPRISONGS
# Processed: Electric Callboy - TEKKNO
# Processed: Standly - Pégate
# Processed: NAYEON - IM NAYEON
# Processed: Rosa Linn - SNAP
# Processed: Randy Houser - Note To Self
# Processed: Kylie Morgan - P.S.
# Processed: Drake - Honestly, Nevermind
# Processed: Rihanna - Black Panther: Wakanda Forever - Music From and Inspired By
# Processed: Hz Catchers - Peaceful Noise
# Processed: Hailey Whitters - Raised
# Processed: LE SSERAFIM - FEARLESS
# Processed: Connor Kauffman - Bleed
# Processed: Aska Mill - White Noise Basic
# Processed: Lucky Daye - Candydrip
# Processed: Hermanos Gutiérrez - El Bueno Y El Malo
# Processed: DPR IAN - Moodswings In To Order
# Processed: Libianca - People
# Processed: Marlon Craft - While We're Here
# Processed: Oscar Maydon - Los Collares
# Processed: Libronics - Sky Full Of Noise
# Processed: Phoebe Bridgers - So Much Wine
# Processed: Jaymes Young - Feel Something (Deluxe)
# Processed: Dean Lewis - How Do I Say Goodbye
# Processed: Jagwar Twin - 33
# Processed: Øneheart - watching the stars
# Processed: Lilly Almberg - Cloud White Noise
# Processed: ZOMBIES – Cast - ZOMBIES 3 (Original Soundtrack)
# Processed: Luke Combs - The Kind of Love We Make
# Processed: Nicki Minaj - Queen Radio: Volume 1
# Processed: j-hope - Jack In The Box
# Processed: Memphis May Fire - Make Believe
# Processed: Memphis May Fire - Remade In Misery
# Processed: La Maquinaria Norteña - Al Derecho Y Al Reverso
# Processed: Øneheart - snowfall (Slowed + Reverb)
# Processed: Lucky da P - MUDDY BUDDY
# Processed: Fuerza Regida - Bebe Dame
# Processed: Drake Milligan - Dallas/Fort Worth
# Processed: Slipknot - The End, So Far
# Processed: Thee Sacred Souls - Love Is The Way
# Processed: Chris Brown - Breezy
# Processed: Grupo Los de la O - Pura Manzanita Vol. 3
# Processed: mgk - mainstream sellout (life in pink deluxe)
# Processed: Pusha T - It's Almost Dry
# Processed: Lavern - Sunshine
# Processed: Kenia OS - K23
# Processed: ENHYPEN - DIMENSION : ANSWER
# Processed: Manuel Turizo - La Bachata
# Processed: LE SSERAFIM - ANTIFRAGILE
# Processed: Nigo - I Know NIGO!
# Processed: Peso Pluma - Siempre Pendientes
# Processed: Imagine Dragons - Bones
# Processed: Cozy Bedroom - Good Night Jazz
# Processed: Kenshi Yonezu - KICK BACK
# Processed: Kapa Boy - Tastes Like Velvet
# Processed: Jeremy Riddle - Live in the Prayer Room
# Processed: Noise Factory - The Rhythm Of Noise
# Processed: leadwave - memories
# Processed: Imanbek - Belly Dancer
# Processed: Leah Kate - Alive and Unwell
# Processed: Various Artists - Bridgerton Season Two (Covers from the Netflix Series)
# Processed: Kevin Kaarl - Paris Texas
# Processed: SIX - SIX: LIVE ON OPENING NIGHT (Original Broadway Cast Recording)
# Processed: David Schultz - Christmas Piano (Vol. 5)
# Processed: Louis Tomlinson - Faith In The Future (Deluxe)
# Processed: Mora - PARAÍSO
# Processed: Rauw Alejandro - TRAP CAKE VOL. 2
# Processed: Vance Joy - In Our Own Sweet Time
# Processed: Danny Ocean - @dannocean
# Processed: Ludovico Einaudi - Underwater
# Processed: Derik Fein - Vertigo
# Processed: Megan Moroney - Tennessee Orange
# Processed: Ray LaMontagne - I Was Born To Love You
# Processed: Scientists of Noise - White Noise Vibrations
# Processed: Tyler Hubbard - 5 Foot 9
# Processed: ENHYPEN - MANIFESTO : DAY 1
# Processed: Black Country, New Road - Ants From Up There
# Processed: Dove Cameron - Boyfriend
# Processed: (G)I-DLE - I NEVER DIE
# Processed: Nessa Barrett - dying on the inside
# Processed: Cigarettes After Sex - Pistol
# Processed: Arcángel - Sr. Santos
# Processed: Mitchell Tenpenny - This Is the Heavy
# Processed: Likko Sol - Soothing White Noise Hum
# Processed: Øneheart - apathy
# Processed: Natanael Cano - AMG
# Processed: Carin Leon - Que Vuelvas
# Processed: Alois - Drops During Dream
# Processed: Clinton Kane - MAYBE SOMEDAY IT'LL ALL BE OK
# Processed: Tiësto - 10:35
# Processed: Sabaton - The War to End All Wars
# Processed: Owen Rochester Jazz - All I Want for Christmas Is You
# Processed: Eden Muñoz - Consejos Gratis
# Processed: Scandinavian White Noise - Scandi Noise Vol. 2
# Processed: Arctic Monkeys - The Car
# Processed: Eminem - Curtain Call 2
# Processed: SunKissed Lola - Pasilyo
# Processed: Benson Boone - ROOM FOR 2
# Processed: Emmit Fenn - The Last Dance, Pt 2
# Processed: Remmy Valenzuela - En Vivo Desde El Rancho
# Processed: Hillside Recording - QUIET
# Processed: Brooke Ligertwood - SEVEN (Live)
# Processed: zandros - obsessed
# Processed: Alesso - Words (feat. Zara Larsson)
# Processed: Paleface Swiss - Fear & Dagger
# Processed: Gunna - Banking On Me
# Processed: 1nonly - Step Back!
# Processed: ATEEZ - THE WORLD EP.1 : MOVEMENT
# Processed: PinkPantheress - Boy's a liar
# Processed: Fuerza Regida - 911 (En Vivo)
# Processed: Carin Leon - Cura Local (En Vivo)
# Processed: Morat - SI AYER FUERA HOY
# Processed: Nathan Evans - Wellerman - The Album
# Processed: Little Symphony - Echo Lake
# Processed: Sydney Taylor Band - I Saw Mommy Kissing Santa Claus
# Processed: 6arelyhuman - XOXO (Kisses Hugs)
# Processed: James Hype - Ferrari
# Processed: Grupo Marca Registrada - Solo Me Dejaste
# Processed: State of Waves - Airplane Nap
# Processed: daniel.mp3 - Backroom
# Processed: Bo Burnham - THE INSIDE OUTTAKES
# Processed: Eem Triplin - AWKWARD FREESTYLE
# Processed: ANOTR - Relax My Eyes
# Processed: Steve Luke & Holloway - O Holy Night
# Processed: salem ilese - (MORE) Unsponsored Content
# Processed: Zach Bryan - Summertime Blues
# Processed: Nicki Minaj - Super Freaky Girl
# Processed: EXOA - White Noise Pillow
# Processed: Rich Amiri - ruthless
# Processed: Maverick City Music - Firm Foundation (He Won't)
# Processed: Lady Gaga - Top Gun: Maverick (Music From The Motion Picture)
# Processed: Paris Paloma - the fruits
# Processed: Cottonwood Firing Squad - you missed the best part
# Processed: Fontaines D.C. - Skinty Fia
# Processed: Jacquees - Sincerely For You
# Processed: EMELINE - cinderella's dead
# Processed: DOPE LEMON - Rose Pink Cadillac
# Processed: Exodar - Baby Sleep Brown Noise
# Processed: El Alfa - SABIDURIA
# Processed: TOMORROW X TOGETHER - minisode 2: Thursday's Child
# Processed: Danny Ocean - @dannocean
# Processed: Tauren Wells - Joy In The Morning
# Processed: TWICE - BETWEEN 1&2
# Processed: Blazerod - White Tonality
# Processed: Xella Machina - Sleep Through the Night
# Processed: EKKSTACY - misery
# Processed: Fujii Kaze - LOVE ALL SERVE ALL
# Processed: Dr. Dreammaker - Baby Noise Machine
# Processed: NEIL FRANCES - There is no Neil Frances
# Processed: The Chainsmokers - So Far So Good
# Processed: HAARPER - GIVE ME BRAIN
# Processed: Ofenbach - I
# Processed: Healing Miracle Frequencies - 528 Hz Deep Healing Music
# Processed: Eliza Rose - B.O.T.A. (Baddest Of Them All)
# Processed: LOSTBOYJAY - COULD BE WRONG
# Processed: Grupo Marca Registrada - Si Fuera Fácil
# Processed: Comet 1993 - Reminisce
# Processed: CARRTOONS - Homegrown
# Processed: Rammstein - Zeit
# Processed: Akon - Konvicted (Complete Edition)
# Processed: Dxrk ダーク - RAVE
# Processed: aespa - Girls - The 2nd Mini Album
# Processed: Tornillo - Morena
# Processed: Soundstars - Low Slow Noise
# Processed: Bear McCreary - God of War Ragnarök (Original Soundtrack)
# Processed: La Adictiva - JGL
# Processed: Los Gemelos De Sinaloa - Andamos Mejor
# Processed: PARCEL - Embracing Subsets
# Processed: Kany García - El Amor Que Merecemos
# Processed: The Black Keys - Dropout Boogie
# Processed: Dormant Clouds - White Stars
# Processed: Peaceful Me - White Dream Noise
# Processed: NIKI - Nicole
# Processed: Jin - The Astronaut
# Processed: Montell Fish - love you more than me
# Processed: thủy - girls like me don't cry
# Processed: NAV - Demons Protected By Angels
# Processed: Wonder Eve - Tis the season
# Processed: Jeremih - Late Nights With Jeremih
# Processed: Grupo Marca Registrada - El Rescate
# Processed: 結束バンド - 結束バンド
# Processed: Original Broadway Cast of & Juliet - & Juliet (Original Broadway Cast Recording)
# Processed: Nate Smith - Whiskey On You
# Processed: Coi Leray - Players
# Processed: Patrick Watson - Ode to Vivian (Rework)
# Processed: Gibran Alcocer - Idea 1
# Processed: Blessd - Instagram
# Processed: Paris Paloma - It's Called: Freefall
# Processed: Creepy Nuts - アンサンブル・プレイ
# Processed: KENTENSHI - paranoia
# Processed: Eden Muñoz - Chale
# Processed: Andrea Vanzo - Intimacy Vol. 1
# Processed: Zander Jazz Trio - A Jazzy Christmas
# Processed: SiM - The Rumbling
# Processed: Hojean - Swing
# Processed: Felix Jaehn - Call It Love
# Processed: Maverick City Music - Kingdom Book One
# Processed: Study Boy - Study Time
# Processed: Grupo Origen - Cabron Yo Puedo
# Processed: iñigo quintero - Si No Estás
# Processed: iñigo quintero - Si No Estás
# Processed: SAULT - 11
# Processed: Study Boy - Study Time
# Processed: Bazzi - Infinite Dream
# Processed: Falling In Reverse - Voices In My Head
# Processed: Noah Kahan - Stick Season
# Processed: Zendium - In Somnio
# Processed: Jamie Miller - Broken Memories
# Processed: The Score - Metamorph
# Processed: Chō - Tumbling Sky
# Processed: Dylan Conrique - birthday cake
# Processed: Yan Block - Vacile
# Processed: Øneheart - distorted memories
# Processed: 5ive - Ahmir & Ahmar
# Processed: Burna Boy - Love, Damini
# Processed: Fizzonaut - Scandinavian Air
# Processed: Eminem - The Eminem Show (Expanded Edition)
# Processed: Bladee - Crest
# Processed: Nelly - Still Hot In Herre
# Processed: El Makabelico - Maldito y Bendito Vol. 2
# Processed: George Ezra - Gold Rush Kid (Christmas Edition)
# Processed: El Fantasma - Fuera De Servicio
# Processed: Ab-Soul - HERBERT
# Processed: Naturelle - Water Brown Noise
# Processed: KIRBY - Black Leaves
# Processed: Kordhell - PSYCHX
# Processed: The Weeknd - Dawn FM (Alternate World)
# Processed: Grupo Marca Registrada - El Rescate
# Processed: Central Cee - 23
# Processed: IVE - After LIKE
# Processed: Grupo Los Chavalos - Rolitas Desvalagadas
# Processed: AVAION - Sleepless
# Processed: Andrea Bocelli - A Family Christmas
# Processed: Lizzo - Special
# Processed: MUPP - vendetta!
# Processed: Dream Supplier - Shhh Best Baby Shushers With Pink Noise
# Processed: Eladio Carrion - SEN2 KBRN VOL. 2
# Processed: SYML - I Wanted to Leave
# Processed: Ren - Hi Ren
# Processed: imase - POP CUBE
# Processed: Backstreet Boys - A Very Backstreet Christmas
# Processed: HAARPER - iCARUS
# Processed: Camila Cabello - Familia
# Processed: Young Miko - TRAP KITTY
# Processed: Wuki - Edge of Seventeen
# Processed: SEVENTEEN - SEVENTEEN 4th Album Repackage 'SECTOR 17'
# Processed: Rema - Rave & Roses
# Processed: Wisin & Yandel - La Última Misión
# Processed: Ha*Ash - Haashtag
# Processed: Supermode - Tell Me Why (MEDUZA Remix)
# Processed: Disco Lines - Baby Girl
# Processed: KXLLSWXTCH - WASTE
# Processed: Ex Habit - Who Do You Want
# Processed: James Jackson Jazz Trio - Easy Dreamin'
# Processed: IVE - LOVE DIVE
# Processed: Nature Field Recordings - Serene Rain Soundscapes
# Processed: Saint Avangeline - Gardener of Eden
# Processed: (G)I-DLE - I love
# Processed: Graydon Poole - Hark! The Herald Angels Sing
# Processed: Kygo - Thrill Of The Chase
# Processed: Victor Cibrian - En El Radio Un Cochinero
# Processed: Jesper Kyd - Warhammer 40,000: Darktide (Original Soundtrack)
# Processed: SUICIDAL-IDOL - ecstacy
# Processed: Miley Cyrus - ATTENTION: MILEY LIVE
# Processed: g3ox_em - GigaChad Theme (Phonk House Version)
# Processed: Tove Lo - Dirt Femme
# Processed: Blessd - Siempre Blessd
# Processed: noturgf - Do Ya Like X Resonance
# Processed: Patrick Watson - Better in the Shade
# Processed: Wunderhorse - Cub
# Processed: Nathan Dawe - 21 Reasons (feat. Ella Henderson)
# Processed: Catherine Russell - Send For Me
# Processed: Kapa Boy - Fine line (Instrumental)
# Processed: In Natura - ETERNAL RAIN
# Processed: Blxst - Before You Go
# Processed: Red Hot Chili Peppers - Unlimited Love
# Processed: Ari Abdul - BABYDOLL (Speed)
# Processed: The Kid LAROI - THOUSAND MILES
# Processed: Entrainment - 888 Hz Attract and Manifest Money
# Processed: Mau P - Drugs From Amsterdam
# Processed: El BAI - Pensándote
# Processed: Weather Modifier - Bajo el paraguas
# Processed: Lexi Jayde - closer to closure
# Processed: Sleep Fruits Music - Sleep Rain, Vol. 2
# Processed: Armani White - BILLIE EILISH.
# Processed: Stephen Dawes - Teenage Dream
# Processed: Naturelle - Restful White Noise
# Processed: KAROL G - PROVENZA
# Processed: Freyr - Misty Rain
# Processed: daniel.mp3 - Gods creation
# Processed: RealestK - Dreams 2 Reality
# Processed: Unjaps - Isolated
# Processed: Neo Si - Stratus
# Processed: Elton John - Hold Me Closer
# Processed: Mau y Ricky - Llorar y Llorar (con Carin Leon)
# Processed: Ñengo Flow - Gato de Noche
# Processed: Avril Lavigne - Love Sux
# Processed: PALOMAZO NORTEÑO - PALOMAZO NORTEÑO (En Vivo Desde El Domo Care)
# Processed: Dom Dolla - Miracle Maker
# Processed: Lil Nas X - STAR WALKIN' (League of Legends Worlds Anthem)
# Processed: Christian Kuria - Suspension of Disbelief
# Processed: Elvis Presley - Elvis 30 #1 Hits (Expanded Edition)
# Processed: berlioz - nyc in 1940
# Processed: Austin Farwell - Once Upon a Time
# Processed: Lil Tjay - In My Head
# Processed: Ο Ήχος της Βροχής - Ήρεμη ελληνική καλοκαιρινή βροχή
# Processed: Camilo - De Adentro Pa Afuera
# Processed: 5Star - Cmonnn (Hit It One Time)(feat. Lay Bankz)
# Processed: iann dior - on to better things
# Processed: Lauv - All 4 Nothing
# Processed: Sarz - Monalisa
# Processed: Grupo Frontera - No Se Va (EN VIVO)
# Processed: Jay Chou - 最偉大的作品
# Processed: Snow Strippers - The Snow Strippers
# Processed: Knucks - ALPHA PLACE
# Processed: Dei V - VVS
# Processed: King George - Keep On Rollin
# Processed: Sleep Fruits Music - Sleep Rain, Vol. 1
# Processed: Heaven Pierce Her - Ultrakill: Imperfect Hatred (Original Game Soundtrack)
# Processed: Sofia Carson - Purple Hearts (Original Soundtrack)
# Processed: Rvfv - NASTU
# Processed: Bae Bee - Clair De Lune
# Processed: Ryan Mack - Forever and Ever and Always
# Processed: Jung Kook - Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack]
# Processed: NIKI - Nicole
# Processed: Fast & Furious: The Fast Saga - WORTH NOTHING (feat. Oliver Tree) [Fast & Furious: Drift Tape/Phonk Vol 1]
# Processed: Arcángel - La Jumpa
# Processed: Becky G - MAMIII
# Processed: Swedish House Mafia - Moth To A Flame
# Processed: LonelyEve - The Hills X Creepin X The Color Violet
# Processed: Elusin - SYNFUELS
# Processed: Kapa Boy - Not Allowed
# Processed: Lauren Spencer Smith - Flowers
# Processed: Toby Mai - ANGEL
# Processed: Jay Wheeler - De Mi Para Ti
# Processed: Charlie Puth - CHARLIE
# Processed: RADWIMPS - Suzume (Motion Picture Soundtrack)
# Processed: CityAlight - There Is One Gospel
# Processed: Red Velvet - ‘The ReVe Festival 2022 - Feel My Rhythm’
# Processed: Chris Brown - Breezy
# Processed: Oxlade - KU LO SA - A COLORS SHOW
# Processed: Rihanna - Lift Me Up (From Black Panther: Wakanda Forever - Music From and Inspired By)
# Processed: noel.smt - Je te laisserai de mots
# Processed: Montell Fish - Hotel
# Processed: UnoTheActivist - Limbus 3
# Processed: Chuy Lizarraga y Su Banda Tierra Sinaloense - Partido En Dos
# Processed: Ruger - The Second Wave (Deluxe)
# Processed: Maretu - New Darling
# Processed: Grupo Frontera - Vete
# Processed: De Parranda - Ya Me Entere (En Vivo)
# Processed: Shawn Mendes - When You're Gone
# Processed: Rich Amiri - Havoc
# Processed: Natanael Cano - Morritas
# Processed: Chris Jedi - La Llevo Al Cielo (Ft. Ñengo Flow)
# Processed: Red Hot Chili Peppers - Return of the Dream Canteen
# Processed: Sonora Siguaray - De Mil Maneras
# Processed: Sia - Everyday Is Christmas (Snowman Deluxe Edition)
# Processed: INTERWORLD - RAPTURE
# Processed: Samara Joy - Warm In December (Edit)
# Processed: PSY - PSY 9th
# Processed: Tokischa - Delincuente
# Processed: KAROL G - GATÚBELA
# Processed: Ayra Starr - 19 & Dangerous (Deluxe)
# Processed: El Taiger - Everglades
# Processed: Silent Chills - Night Rain Thunder
# Processed: TWOPILOTS - Riptide
# Processed: Mc_team - Frecuencias Curativas Solfeggio 369 Hz
# Processed: Isabel LaRosa - HEARTBEAT
# Processed: Camila Cabello - Bam Bam (feat. Ed Sheeran)
# Processed: Buddha's Lounge - Yoga Flute Meditation
# Processed: David Guetta - Crazy What Love Can Do
# Processed: MoonDeity - NEON BLADE
# Processed: Jesus Image - JESUS (Live)
# Processed: David Healer - Disney Piano Lullaby Best for Baby
# Processed: Hollywood Undead - Hotel Kalifornia
# Processed: Rels B - cómo dormiste?
# Processed: Dalex - Yo Te Quiero Pa Mi
# Processed: Oh so Tired - Everything's Wet
# Processed: Snow Strippers - April Mixtape 2
# Processed: Central Cee - LET GO
# Processed: Tyga - Sunshine
# Processed: Vince Guaraldi Trio - A Charlie Brown Christmas (2022 Mix)
# Processed: Jax Jones - Where Did You Go (feat. MNEK)
# Processed: Faceless 1-7 - Cut It Bleed It Breathe It
# Processed: Tom Santa - Rainfall (Praise You)
# Processed: Grupo Frontera - Si Yo Fuera Ladrón
# Processed: 2hollis - White Tiger
# Processed: Duskus - Let Go
# Processed: David Schultz - Julmusik på piano (Vol. 2)
# Processed: Alex Rose - ENR
# Processed: Tom Odell - Best Day of My Life
# Processed: Shakira - Te Felicito
# Processed: Sofía Reyes - Mal De Amores
# Processed: mazie - the rainbow cassette (bonus)
# Processed: a vow - you don't know what to feel anymore
# Processed: John Summit - La Danza
# Processed: SEULGI - 28 Reasons - The 1st Mini Album
# Processed: Ice Spice - Munch (Feelin’ U)
# Processed: RÜFÜS DU SOL - Surrender (Remixes)
# Processed: Cover Kid - Baby Lullabies and Nursery Rhymes: Piano Volume 2
# Processed: Kris Bowers - Bridgerton Season Two (Soundtrack from the Netflix Series)
# Processed: ThxSoMch - Keep It Tucked
# Processed: Vague003 - drowning
# Processed: WILL K - Sun Is Dark
# Processed: Wizkid - More Love, Less Ego
# Processed: Bella Poarch - Dolls EP
# Processed: Øneheart - rain inside
# Processed: Ren - Violet's Tale
# Processed: phonk.me - GHOST!
# Processed: Maretu - aishiteitanoni
# Processed: TAEYEON - INVU - The 3rd Album
# Processed: Blksmiith - 「DIGITAL TWIN」
# Processed: Rema - Calm Down
# Processed: Henry Smith - 00s Piano Covers
# Processed: Holly Humberstone - Can You Afford To Lose Me?
# Processed: Sarai Rivera - Suelto
# Processed: Yaya Bey - Remember Your North Star
# Processed: Chris Brown - Breezy (Deluxe)
# Processed: Milky Chance - Trip Tape II
# Processed: Sleep Therapy Radio - Wet and Windy
# Processed: Lambo4oe - Self Esteem (featuring NLE Choppa)
# Processed: Roddy Ricch - Feed Tha Streets III
# Processed: fam0uz - Kerosene (Slowed)
# Processed: LoFi Waiter - Time Fragments
# Processed: AKUGETSU - Unknown (Till The End...) (VIVINOS - ALNST Original Soundtrack Part.3)
# Processed: LANDMVRKS - Lost in the Waves (The Complete Edition)
# Processed: New West - Those Eyes (Alternate Versions)
# Processed: BONES - AmericanSweetheart
# Processed: Comet 1993 - Natural Blend
# Processed: Matisse - Así de Enamorados
# Processed: Anuel AA - ¿Qué Nos Pasó?
# Processed: James Heather - Invisible Forces
# Processed: Fridayy - Lost In Melody
# Processed: Alex Zurdo - DTOX
# Processed: Oh so Tired - Lashing Down
# Processed: smokedope2016 - IM NOT GOD BUT I WISH I WAS (feat. Joeyy)
# Processed: Xantesha - SUNRISE (Slowed + Reverb)
# Processed: Paloma Faith - Only Love Can Hurt Like This (feat. Teddy Swims) [Remix]
# Processed: David Guetta - Satisfaction
# Processed: BIBI - Lowlife Princess: Noir
# Processed: SCXR SOUL - DEMONS IN MY SOUL
# Processed: Calum Scott - Bridges
# Processed: PLÜM - Stay
# Processed: The Cast of Roald Dahl's Matilda The Musical - Roald Dahl's Matilda The Musical (Soundtrack from the Netflix Film)
# Processed: Baby Fruits Music - Baby Fruits Remix, Vol. 1
# Processed: daniel.mp3 - 3 am empty
# Processed: Stromae - Multitude
# Processed: Yami Safdie - Dije Que No Me Iba a Enamorar
# Processed: Suriel Hess - Little Bit More
# Processed: Antonín Dvořák - Dvořák: Greatest Melodies (Arr. P. Breiner for Piano)
# Processed: Natalia Lafourcade - De Todas las Flores
# Processed: Tyga - Freaky Deaky
# Processed: analog_mannequin - milk cassette x.mp3 (slowed + reverb)
# Processed: Charlie Puth - Left and Right (Feat. Jung Kook of BTS)
# Processed: Nemzzz - 2MS
# Processed: piri - froge.mp3
# Processed: Yandel - Yandel 150
# Processed: Yarden - Wetin
# Processed: NMIXX - ENTWURF
# Processed: C!naH - Sweet Dream (VIVINOS - ALNST Original Soundtrack Part.2)
# Processed: NEEDY GIRL OVERDOSE - [NEEDY STREAMER OVERLOAD] Soundtrack
# Processed: Megami - Star Shopping
# Processed: Henry Smith - 90s Piano Covers (Vol. 1)
# Processed: Headspace - Relax
# Processed: ROSALÍA - DESPECHÁ
# Processed: Palaye Royale - Fever Dream
# Processed: Shakira - Monotonía
# Processed: Jung Kook - Stay Alive (Prod. SUGA of BTS)
# Processed: Tasha Layton - This is Christmas
# Processed: 25時、ナイトコードで。 - 25時、ナイトコードで。 SEKAI ALBUM vol.1
# Processed: Pepe Aguilar - Pepe Aguilar te Acompaña en Navidad
# Processed: W&W - Heaven Is A Place On Earth
# Processed: Bonobo - Fragments
# Processed: Banda Elemental de Mazatlán Sinaloa - Una Raya Más al Tigre
# Processed: Izzamuzzic - Shootout
# Processed: The Brownian Sleepers - Brown Noise Lullaby
# Processed: imase - NIGHT DANCER
# Processed: Trueno - BIEN O MAL
# Processed: REAPER - DISRUPTOR LP
# Processed: Oasis Ministry - Hijos (Live)
# Processed: Crash Adams - Give Me a Kiss
# Processed: Pedro Capó - La Neta
# Processed: Parkway Drive - Darker Still
# Processed: Architects - the classic symptoms of a broken spirit
# Processed: Cris Mj - Marisola (Remix)
# Processed: akiaura - veil
# Processed: Archer Marsh - Sequēns
# Processed: Nessa Barrett - young forever (extended)
# Processed: Piso 21 - 777
# Processed: Little Simz - NO THANK YOU
# Processed: BCCF - My White Noise
# Processed: Antent - Pulse
# Processed: Cazzu - Nena Trampa
# Processed: Invention of Light - Just White Noise Vol 1: 1 Hour of Seamless White Noise to Wrap You in a Blanket of Blissful Sleep
# Processed: Toby Mai - nobody
# Processed: CKay - Sad Romance
# Processed: Punctual - Do It All Again
# Processed: Greeicy - La Carta
# Processed: LSPLASH - Doors (Original Game Soundtrack), Vol. 1
# Processed: Muse - Will Of The People
