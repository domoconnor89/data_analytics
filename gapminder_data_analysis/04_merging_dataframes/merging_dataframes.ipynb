# %% [markdown]
# # Merging Dataframes
# <hr style="border:2px solid black">

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### Key Concepts

# %% [markdown]
# |command|	description|
# |:--:|:--:|
# |`df1.merge(df2)`|	joins two dataframes horizontally, based on specific indexes/columns|
# |`pd.concat([df1,df2])`|joins two or more datarames vertically together|

# %% [markdown]
# **load packages**

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# **read the penguins_mini (as df1) and penguins_region (as df2)**

# %%
df1 = pd.read_csv('./data/penguins_mini.csv')
df1.head()
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex
# 0     Adelie  Torgersen              181.0       3750.0    male
# 1     Adelie      Dream              178.0       3900.0    male
# 2     Gentoo     Biscoe              211.0       4500.0  female
# 3     Gentoo     Biscoe              230.0       5700.0    male
# 4  Chinstrap      Dream              192.0       3500.0  female

# %%
df2 = pd.read_csv('./data/penguins_region.csv')
df2.head()
# Out:
#      species            region
# 0     Adelie            Anvers
# 1       King  Tierra del Fuego
# 2    Emperor       Weddell sea
# 3  Chinstrap            Anvers
# 4     Gentoo            Anvers

# %% [markdown]
# **The `concat` function can be compared to what `.append()` is for lists.

# %%
df1.append(df2)
# Out:
# /var/folders/zf/w4lxv8m15z9442k97fpp97ch0000gn/T/ipykernel_6713/3062608662.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2)
#        species     island  flipper_length_mm  body_mass_g     sex  \
# 0       Adelie  Torgersen              181.0       3750.0    male
# 1       Adelie      Dream              178.0       3900.0    male
# 2       Gentoo     Biscoe              211.0       4500.0  female
# 3       Gentoo     Biscoe              230.0       5700.0    male
# 4    Chinstrap      Dream              192.0       3500.0  female
# 0       Adelie        NaN                NaN          NaN     NaN
# 1         King        NaN                NaN          NaN     NaN
# 2      Emperor        NaN                NaN          NaN     NaN
# 3    Chinstrap        NaN                NaN          NaN     NaN
# 4       Gentoo        NaN                NaN          NaN     NaN
# 5  Little Blue        NaN                NaN          NaN     NaN
#
#              region
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 0            Anvers
# 1  Tierra del Fuego
# 2       Weddell sea
# 3            Anvers
# 4            Anvers
# 5   Roaring Forties

# %% [markdown]
# <hr style="border:2px solid black">

# %% [markdown]
# ## 2. Concatenation

# %% [markdown]
# - concatenate pandas dataframes along a particular axis with optional set logic along the other axes
# - axis = 0 is vertically and axis = 1 is horizontally
# - can combine multiple dataframes
# - there are several parameters that decide how the concatenation is done, most important are **axis**, **ignore_index** and **sort**
# - main use when **axis=0** is when df1 and df2 have the **same columns**
# - main use when **axis = 1** is when df1 and df2 have the **different columns** of the same observations

# %%
pd.concat([df1, df2]) # we are passing the dataframes as a list
# notice how the non existent columns in both dataframes are filled with null values
# notice how the index remains unchanged
# Out:
#        species     island  flipper_length_mm  body_mass_g     sex  \
# 0       Adelie  Torgersen              181.0       3750.0    male
# 1       Adelie      Dream              178.0       3900.0    male
# 2       Gentoo     Biscoe              211.0       4500.0  female
# 3       Gentoo     Biscoe              230.0       5700.0    male
# 4    Chinstrap      Dream              192.0       3500.0  female
# 0       Adelie        NaN                NaN          NaN     NaN
# 1         King        NaN                NaN          NaN     NaN
# 2      Emperor        NaN                NaN          NaN     NaN
# 3    Chinstrap        NaN                NaN          NaN     NaN
# 4       Gentoo        NaN                NaN          NaN     NaN
# 5  Little Blue        NaN                NaN          NaN     NaN
#
#              region
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 0            Anvers
# 1  Tierra del Fuego
# 2       Weddell sea
# 3            Anvers
# 4            Anvers
# 5   Roaring Forties

# %%
# axis=0

pd.concat([df1, df2], axis=0)
# Out:
#        species     island  flipper_length_mm  body_mass_g     sex  \
# 0       Adelie  Torgersen              181.0       3750.0    male
# 1       Adelie      Dream              178.0       3900.0    male
# 2       Gentoo     Biscoe              211.0       4500.0  female
# 3       Gentoo     Biscoe              230.0       5700.0    male
# 4    Chinstrap      Dream              192.0       3500.0  female
# 0       Adelie        NaN                NaN          NaN     NaN
# 1         King        NaN                NaN          NaN     NaN
# 2      Emperor        NaN                NaN          NaN     NaN
# 3    Chinstrap        NaN                NaN          NaN     NaN
# 4       Gentoo        NaN                NaN          NaN     NaN
# 5  Little Blue        NaN                NaN          NaN     NaN
#
#              region
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 0            Anvers
# 1  Tierra del Fuego
# 2       Weddell sea
# 3            Anvers
# 4            Anvers
# 5   Roaring Forties

# %% [markdown]
# #### Can I concat 3 dataframes?

# %%
penguin_sweet = {'species': ['Adelie', 'Gentoo', 'Chinstrap'], 
          'sweetness': ['sweet', 'sweeter', 'sweetest']}
df3 = pd.DataFrame(penguin_sweet)
df3
# Out:
#      species sweetness
# 0     Adelie     sweet
# 1     Gentoo   sweeter
# 2  Chinstrap  sweetest

# %%
pd.concat([df1,df2,df3])
# Out:
#        species     island  flipper_length_mm  body_mass_g     sex  \
# 0       Adelie  Torgersen              181.0       3750.0    male
# 1       Adelie      Dream              178.0       3900.0    male
# 2       Gentoo     Biscoe              211.0       4500.0  female
# 3       Gentoo     Biscoe              230.0       5700.0    male
# 4    Chinstrap      Dream              192.0       3500.0  female
# 0       Adelie        NaN                NaN          NaN     NaN
# 1         King        NaN                NaN          NaN     NaN
# 2      Emperor        NaN                NaN          NaN     NaN
# 3    Chinstrap        NaN                NaN          NaN     NaN
# 4       Gentoo        NaN                NaN          NaN     NaN
# 5  Little Blue        NaN                NaN          NaN     NaN
# 0       Adelie        NaN                NaN          NaN     NaN
# 1       Gentoo        NaN                NaN          NaN     NaN
# 2    Chinstrap        NaN                NaN          NaN     NaN
#
#              region sweetness
# 0               NaN       NaN
# 1               NaN       NaN
# 2               NaN       NaN
# 3               NaN       NaN
# 4               NaN       NaN
# 0            Anvers       NaN
# 1  Tierra del Fuego       NaN
# 2       Weddell sea       NaN
# 3            Anvers       NaN
# 4            Anvers       NaN
# 5   Roaring Forties       NaN
# 0               NaN     sweet
# 1               NaN   sweeter
# 2               NaN  sweetest

# %% [markdown]
# #### Adding Parameters

# %%
# notice how the index is now correct
# notice how the columns are sorted alphabetically and the rows are sorted according to first column

pd.concat([df1, df2], axis=0, ignore_index=True, sort=True)

#sort : bool, default False
#Sort non-concatenation axis (axis=0, x-axis) if it is not already aligned when `join` is 'outer'.
#This has no effect when ``join='inner'``, which already preserves the order of the non-concatenation axis.
# Out:
#     body_mass_g  flipper_length_mm     island            region     sex  \
# 0        3750.0              181.0  Torgersen               NaN    male
# 1        3900.0              178.0      Dream               NaN    male
# 2        4500.0              211.0     Biscoe               NaN  female
# 3        5700.0              230.0     Biscoe               NaN    male
# 4        3500.0              192.0      Dream               NaN  female
# 5           NaN                NaN        NaN            Anvers     NaN
# 6           NaN                NaN        NaN  Tierra del Fuego     NaN
# 7           NaN                NaN        NaN       Weddell sea     NaN
# 8           NaN                NaN        NaN            Anvers     NaN
# 9           NaN                NaN        NaN            Anvers     NaN
# 10          NaN                NaN        NaN   Roaring Forties     NaN
#
#         species
# 0        Adelie
# 1        Adelie
# 2        Gentoo
# 3        Gentoo
# 4     Chinstrap
# 5        Adelie
# 6          King
# 7       Emperor
# 8     Chinstrap
# 9        Gentoo
# 10  Little Blue

# %%
# axis=1
pd.concat([df1, df2], axis=1)
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex      species  \
# 0     Adelie  Torgersen              181.0       3750.0    male       Adelie
# 1     Adelie      Dream              178.0       3900.0    male         King
# 2     Gentoo     Biscoe              211.0       4500.0  female      Emperor
# 3     Gentoo     Biscoe              230.0       5700.0    male    Chinstrap
# 4  Chinstrap      Dream              192.0       3500.0  female       Gentoo
# 5        NaN        NaN                NaN          NaN     NaN  Little Blue
#
#              region
# 0            Anvers
# 1  Tierra del Fuego
# 2       Weddell sea
# 3            Anvers
# 4            Anvers
# 5   Roaring Forties

# %% [markdown]
# <hr style="border:2px solid black">

# %% [markdown]
# ## 3. Merging

# %% [markdown]
# <img src='joins.png' width=500>

# %% [markdown]
# ### 3.1 Inner Join

# %% [markdown]
# - will merge dataframes with a database-style **inner** join
# - one column must be in common between the dataframes
# - inner join means only taking the rows in common based on the join column

# %%
df1
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex
# 0     Adelie  Torgersen              181.0       3750.0    male
# 1     Adelie      Dream              178.0       3900.0    male
# 2     Gentoo     Biscoe              211.0       4500.0  female
# 3     Gentoo     Biscoe              230.0       5700.0    male
# 4  Chinstrap      Dream              192.0       3500.0  female

# %%
df2
# Out:
#        species            region
# 0       Adelie            Anvers
# 1         King  Tierra del Fuego
# 2      Emperor       Weddell sea
# 3    Chinstrap            Anvers
# 4       Gentoo            Anvers
# 5  Little Blue   Roaring Forties

# %%
# method 1

pd.merge(df1, df2, how='inner', on='species')

# no King, Emperor, or Little Blue... not common variables so 'inner' ignores
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex  region
# 0     Adelie  Torgersen              181.0       3750.0    male  Anvers
# 1     Adelie      Dream              178.0       3900.0    male  Anvers
# 2     Gentoo     Biscoe              211.0       4500.0  female  Anvers
# 3     Gentoo     Biscoe              230.0       5700.0    male  Anvers
# 4  Chinstrap      Dream              192.0       3500.0  female  Anvers

# %%
# method 2

df1.merge(df2, how='inner', on='species')
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex  region
# 0     Adelie  Torgersen              181.0       3750.0    male  Anvers
# 1     Adelie      Dream              178.0       3900.0    male  Anvers
# 2     Gentoo     Biscoe              211.0       4500.0  female  Anvers
# 3     Gentoo     Biscoe              230.0       5700.0    male  Anvers
# 4  Chinstrap      Dream              192.0       3500.0  female  Anvers

# %%
pd.merge(df1, df2) # if there is only one common column, this will also work

# inner join is the default and will merge on the only common column (in this case, 'species')
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex  region
# 0     Adelie  Torgersen              181.0       3750.0    male  Anvers
# 1     Adelie      Dream              178.0       3900.0    male  Anvers
# 2     Gentoo     Biscoe              211.0       4500.0  female  Anvers
# 3     Gentoo     Biscoe              230.0       5700.0    male  Anvers
# 4  Chinstrap      Dream              192.0       3500.0  female  Anvers

# %% [markdown]
# ### 3.2 Right Join

# %% [markdown]
# - will merge dataframes with a database-style **right** join
# - one column must be in common between the dataframes
# - right join means taking all the rows in the right dataframe
# - missing rows from the left dataframe will be filled with null values

# %% [markdown]
# <img src='joins.png' width=500>

# %%
df1
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex
# 0     Adelie  Torgersen              181.0       3750.0    male
# 1     Adelie      Dream              178.0       3900.0    male
# 2     Gentoo     Biscoe              211.0       4500.0  female
# 3     Gentoo     Biscoe              230.0       5700.0    male
# 4  Chinstrap      Dream              192.0       3500.0  female

# %%
df2
# Out:
#        species            region
# 0       Adelie            Anvers
# 1         King  Tierra del Fuego
# 2      Emperor       Weddell sea
# 3    Chinstrap            Anvers
# 4       Gentoo            Anvers
# 5  Little Blue   Roaring Forties

# %%
# method 1

pd.merge(right=df1, left=df2, how='right', on='species')
# Out:
#      species  region     island  flipper_length_mm  body_mass_g     sex
# 0     Adelie  Anvers  Torgersen              181.0       3750.0    male
# 1     Adelie  Anvers      Dream              178.0       3900.0    male
# 2     Gentoo  Anvers     Biscoe              211.0       4500.0  female
# 3     Gentoo  Anvers     Biscoe              230.0       5700.0    male
# 4  Chinstrap  Anvers      Dream              192.0       3500.0  female

# %%
# method 2

# notice how the order in this syntax is important!!!

df2.merge(df1, how='right', on='species')
# Out:
#      species  region     island  flipper_length_mm  body_mass_g     sex
# 0     Adelie  Anvers  Torgersen              181.0       3750.0    male
# 1     Adelie  Anvers      Dream              178.0       3900.0    male
# 2     Gentoo  Anvers     Biscoe              211.0       4500.0  female
# 3     Gentoo  Anvers     Biscoe              230.0       5700.0    male
# 4  Chinstrap  Anvers      Dream              192.0       3500.0  female

# %% [markdown]
# ### 3.3 Left Join

# %% [markdown]
# - will merge dataframes with a database-style **left** join
# - one column must be in common between the dataframes
# - left join means taking all the rows in the left dataframe
# - missing rows from the right dataframe will be filled with null values

# %%
# method 1

pd.merge(right=df1, left=df2, how='left', on='species')
# Out:
#        species            region     island  flipper_length_mm  body_mass_g  \
# 0       Adelie            Anvers  Torgersen              181.0       3750.0
# 1       Adelie            Anvers      Dream              178.0       3900.0
# 2         King  Tierra del Fuego        NaN                NaN          NaN
# 3      Emperor       Weddell sea        NaN                NaN          NaN
# 4    Chinstrap            Anvers      Dream              192.0       3500.0
# 5       Gentoo            Anvers     Biscoe              211.0       4500.0
# 6       Gentoo            Anvers     Biscoe              230.0       5700.0
# 7  Little Blue   Roaring Forties        NaN                NaN          NaN
#
#       sex
# 0    male
# 1    male
# 2     NaN
# 3     NaN
# 4  female
# 5  female
# 6    male
# 7     NaN

# %%
# method 2

df2.merge(df1, how='left', on='species')
# Out:
#        species            region     island  flipper_length_mm  body_mass_g  \
# 0       Adelie            Anvers  Torgersen              181.0       3750.0
# 1       Adelie            Anvers      Dream              178.0       3900.0
# 2         King  Tierra del Fuego        NaN                NaN          NaN
# 3      Emperor       Weddell sea        NaN                NaN          NaN
# 4    Chinstrap            Anvers      Dream              192.0       3500.0
# 5       Gentoo            Anvers     Biscoe              211.0       4500.0
# 6       Gentoo            Anvers     Biscoe              230.0       5700.0
# 7  Little Blue   Roaring Forties        NaN                NaN          NaN
#
#       sex
# 0    male
# 1    male
# 2     NaN
# 3     NaN
# 4  female
# 5  female
# 6    male
# 7     NaN

# %% [markdown]
# #### Using `indicator=True` to check how the dataframes were merged and if it corresponds to your expectations

# %%
df2.merge(df1, how='left', on='species', indicator=True)

# this shows where the outputted DF variables have come from... 
#... as this is left join, the merge column will only show 'both', or 'left'
# Out:
#        species            region     island  flipper_length_mm  body_mass_g  \
# 0       Adelie            Anvers  Torgersen              181.0       3750.0
# 1       Adelie            Anvers      Dream              178.0       3900.0
# 2         King  Tierra del Fuego        NaN                NaN          NaN
# 3      Emperor       Weddell sea        NaN                NaN          NaN
# 4    Chinstrap            Anvers      Dream              192.0       3500.0
# 5       Gentoo            Anvers     Biscoe              211.0       4500.0
# 6       Gentoo            Anvers     Biscoe              230.0       5700.0
# 7  Little Blue   Roaring Forties        NaN                NaN          NaN
#
#       sex     _merge
# 0    male       both
# 1    male       both
# 2     NaN  left_only
# 3     NaN  left_only
# 4  female       both
# 5  female       both
# 6    male       both
# 7     NaN  left_only

# %% [markdown]
# ### 3.4 Outer Join

# %% [markdown]
# - will merge dataframes with a database-style **outer** join
# - one column must be in common between the dataframes
# - outer join means taking all the rows from both dataframes
# - missing rows from both dataframes will be filled with null values

# %%
df1
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex
# 0     Adelie  Torgersen              181.0       3750.0    male
# 1     Adelie      Dream              178.0       3900.0    male
# 2     Gentoo     Biscoe              211.0       4500.0  female
# 3     Gentoo     Biscoe              230.0       5700.0    male
# 4  Chinstrap      Dream              192.0       3500.0  female

# %%
df2
# Out:
#        species            region
# 0       Adelie            Anvers
# 1         King  Tierra del Fuego
# 2      Emperor       Weddell sea
# 3    Chinstrap            Anvers
# 4       Gentoo            Anvers
# 5  Little Blue   Roaring Forties

# %%
# method 1

pd.merge(right=df1, left=df2, how='outer', on='species')
# Out:
#        species            region     island  flipper_length_mm  body_mass_g  \
# 0       Adelie            Anvers  Torgersen              181.0       3750.0
# 1       Adelie            Anvers      Dream              178.0       3900.0
# 2         King  Tierra del Fuego        NaN                NaN          NaN
# 3      Emperor       Weddell sea        NaN                NaN          NaN
# 4    Chinstrap            Anvers      Dream              192.0       3500.0
# 5       Gentoo            Anvers     Biscoe              211.0       4500.0
# 6       Gentoo            Anvers     Biscoe              230.0       5700.0
# 7  Little Blue   Roaring Forties        NaN                NaN          NaN
#
#       sex
# 0    male
# 1    male
# 2     NaN
# 3     NaN
# 4  female
# 5  female
# 6    male
# 7     NaN

# %%
# sort=True will sort the rows on the spice column alphabetically 

pd.merge(right=df1, left=df2, how='outer', on='species', sort=True)
# Out:
#        species            region     island  flipper_length_mm  body_mass_g  \
# 0       Adelie            Anvers  Torgersen              181.0       3750.0
# 1       Adelie            Anvers      Dream              178.0       3900.0
# 2    Chinstrap            Anvers      Dream              192.0       3500.0
# 3      Emperor       Weddell sea        NaN                NaN          NaN
# 4       Gentoo            Anvers     Biscoe              211.0       4500.0
# 5       Gentoo            Anvers     Biscoe              230.0       5700.0
# 6         King  Tierra del Fuego        NaN                NaN          NaN
# 7  Little Blue   Roaring Forties        NaN                NaN          NaN
#
#       sex
# 0    male
# 1    male
# 2  female
# 3     NaN
# 4  female
# 5    male
# 6     NaN
# 7     NaN

# %%
df1
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex
# 0     Adelie  Torgersen              181.0       3750.0    male
# 1     Adelie      Dream              178.0       3900.0    male
# 2     Gentoo     Biscoe              211.0       4500.0  female
# 3     Gentoo     Biscoe              230.0       5700.0    male
# 4  Chinstrap      Dream              192.0       3500.0  female

# %%
df2
# Out:
#        species            region
# 0       Adelie            Anvers
# 1         King  Tierra del Fuego
# 2      Emperor       Weddell sea
# 3    Chinstrap            Anvers
# 4       Gentoo            Anvers
# 5  Little Blue   Roaring Forties

# %%
# method 2

df1.merge(df2, how='outer', on='species')
# Out:
#        species     island  flipper_length_mm  body_mass_g     sex  \
# 0       Adelie  Torgersen              181.0       3750.0    male
# 1       Adelie      Dream              178.0       3900.0    male
# 2       Gentoo     Biscoe              211.0       4500.0  female
# 3       Gentoo     Biscoe              230.0       5700.0    male
# 4    Chinstrap      Dream              192.0       3500.0  female
# 5         King        NaN                NaN          NaN     NaN
# 6      Emperor        NaN                NaN          NaN     NaN
# 7  Little Blue        NaN                NaN          NaN     NaN
#
#              region
# 0            Anvers
# 1            Anvers
# 2            Anvers
# 3            Anvers
# 4            Anvers
# 5  Tierra del Fuego
# 6       Weddell sea
# 7   Roaring Forties

# %%
df2.merge(df1, how='outer', on='species', sort=True)
# Out:
#        species            region     island  flipper_length_mm  body_mass_g  \
# 0       Adelie            Anvers  Torgersen              181.0       3750.0
# 1       Adelie            Anvers      Dream              178.0       3900.0
# 2    Chinstrap            Anvers      Dream              192.0       3500.0
# 3      Emperor       Weddell sea        NaN                NaN          NaN
# 4       Gentoo            Anvers     Biscoe              211.0       4500.0
# 5       Gentoo            Anvers     Biscoe              230.0       5700.0
# 6         King  Tierra del Fuego        NaN                NaN          NaN
# 7  Little Blue   Roaring Forties        NaN                NaN          NaN
#
#       sex
# 0    male
# 1    male
# 2  female
# 3     NaN
# 4  female
# 5    male
# 6     NaN
# 7     NaN
